# %% [markdown]
# # Level 5: Debug, visualize and find performance bottlenecks

# %% [markdown]
# ## Debug your model (basic)

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader, random_split
import torch.nn.functional as F

from lightning import LightningModule
from lightning import Trainer
from lightning.pytorch.callbacks import ModelCheckpoint
from lightning.pytorch.callbacks import EarlyStopping
from lightning.pytorch.callbacks import ModelSummary
from lightning.pytorch.loggers import CSVLogger

from torchvision import datasets
import torchvision.transforms as transforms

import os

# %%
# Load data sets
transform = transforms.ToTensor()
train_set = datasets.MNIST(root="../data/MNIST", download=True, train=True, transform=transform)
test_set = datasets.MNIST(root="../data/MNIST", download=True, train=False, transform=transform)

# use 20% of training data for validation
train_set_size = int(len(train_set) * 0.8)
valid_set_size = len(train_set) - train_set_size

# split the train set into two
seed = torch.Generator().manual_seed(42)
train_set, valid_set = random_split(train_set, [train_set_size, valid_set_size], generator=seed)

train_loader = DataLoader(train_set, batch_size=128, shuffle=True, num_workers=16, persistent_workers=True, pin_memory=True)
valid_loader = DataLoader(valid_set, batch_size=128, num_workers=16, persistent_workers=True, pin_memory=True)
test_loader = DataLoader(test_set, batch_size=1024, num_workers=16, persistent_workers=True, pin_memory=True)

# %%
class Encoder(nn.Module):
    def __init__(self, in_dim=28*28, hidden_nodes_1=64, hidden_nodes_2=64, out_dim=4):
        super().__init__()
        self.ff = nn.Sequential(
            nn.Linear(in_dim, hidden_nodes_1),
            nn.ReLU(),
            nn.Linear(hidden_nodes_1, hidden_nodes_2),
            nn.ReLU(),
            nn.Linear(hidden_nodes_2, out_dim)
        )

    def forward(self, x):
        return self.ff(x)

class Decoder(nn.Module):
    def __init__(self, in_dim=4, hidden_nodes_1=64, hidden_nodes_2=64, out_dim=28*28):
        super().__init__()
        self.ff = nn.Sequential(
            nn.Linear(in_dim, hidden_nodes_1),
            nn.ReLU(),
            nn.Linear(hidden_nodes_1, hidden_nodes_2),
            nn.ReLU(),
            nn.Linear(hidden_nodes_2, out_dim)
        )

    def forward(self, x):
        return self.ff(x)

class LitAutoEncoder(LightningModule):
    def __init__(self, encoder, decoder, lr=1e-5, example_input_array=None):
        super().__init__()
        self.example_input_array = example_input_array
        self.encoder = encoder
        self.decoder = decoder
        self.lr = lr
        self.save_hyperparameters(ignore=["encoder", "decoder"])

    def training_step(self, batch, batch_idx):
        # training_step defines the train loop.
        loss = self._get_loss(batch)
        self.log("train/loss", loss, on_step=True, on_epoch=True)
        self.log("train_loss", loss, prog_bar=True, on_step=False, on_epoch=True)
        return loss

    def validation_step(self, batch, batch_idx):
        # this is the validation loop
        loss = self._get_loss(batch)
        self.log("val_loss", loss, prog_bar=True)

    def test_step(self, batch, batch_idx):
        # this is the test loop
        loss = self._get_loss(batch)
        self.log("test_loss", loss)

    def _get_loss(self, batch):
        x, _ = batch
        x = x.view(x.size(0), -1)
        x_hat = self.forward(x)
        loss = F.mse_loss(x_hat, x)
        return loss

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=self.lr)
        return optimizer

    def forward(self, x):
        z = self.encoder(x)
        x_hat = self.decoder(z)
        return x_hat

# %%
model = LitAutoEncoder(
    encoder=Encoder(
        in_dim=28*28,
        hidden_nodes_1=512,
        hidden_nodes_2=256,
        out_dim=100
    ),
    decoder=Decoder(
        in_dim=100,
        hidden_nodes_1=128,
        hidden_nodes_2=256,
        out_dim=28*28
    )
)

# %%
logger = CSVLogger(
    save_dir='logs',
    name='debugging_tests',
    version=None,
    prefix='test_'
)

checkpoint_callback = ModelCheckpoint(
    dirpath=os.path.join(logger.log_dir, "checkpoints"),
    filename="autoencoder_best-{epoch:02d}-{val_loss:.3f}",
    monitor="val_loss",    
    mode="min",
    save_top_k=3,     # keep ONLY the best
    save_last=True    # ALSO save last.ckpt
)

early_stop_callback = EarlyStopping(
    monitor="val_loss",
    patience=3,
    verbose=False,
    mode="min"
)

# %% [markdown]
# ### Run all your model code once quickly
# see [here](https://lightning.ai/docs/pytorch/stable/debug/debugging_basic.html#run-all-your-model-code-once-quickly:~:text=x**2%20line.-,Run%20all%20your%20model%20code%20once%20quickly,-If%20you%E2%80%99ve%20ever)

# %%
trainer_test = Trainer(
    fast_dev_run=10,
    accelerator="gpu",
    devices=1,
    max_epochs=10
)
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# Running in `fast_dev_run` mode: will run the requested loop using 10 batch(es). Logging and checkpointing is suppressed.

# %%
trainer_test.fit(model, train_loader, valid_loader)
trainer_test.test(model, test_loader)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
#   | Name    | Type    | Params | Mode  | FLOPs
# ----------------------------------------------------
# 0 | encoder | Encoder | 558 K  | train | 0
# 1 | decoder | Decoder | 247 K  | train | 0
# ----------------------------------------------------
# 806 K     Trainable params
# 0         Non-trainable params
# 806 K     Total params
# 3.226     Total estimated model params size (MB)
# 14        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Epoch 0: 100%|██████████| 10/10 [00:00<00:00, 18.25it/s, val_loss=0.113, train_loss=0.110]
# `Trainer.fit` stopped: `max_steps=10` reached.
# Epoch 0: 100%|██████████| 10/10 [00:00<00:00, 18.17it/s, val_loss=0.113, train_loss=0.110]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# Testing DataLoader 0: 100%|██████████| 10/10 [00:00<00:00, 130.08it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_loss           0.1138618141412735
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_loss': 0.1138618141412735}]

# %%
trainer = Trainer(
    logger=logger,
    callbacks=[checkpoint_callback, early_stop_callback],
    accelerator="gpu",
    devices=1,
    max_epochs=10
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores

# %%
trainer.fit(model, train_loader, valid_loader)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
#   | Name    | Type    | Params | Mode  | FLOPs
# ----------------------------------------------------
# 0 | encoder | Encoder | 558 K  | train | 0
# 1 | decoder | Decoder | 247 K  | train | 0
# ----------------------------------------------------
# 806 K     Trainable params
# 0         Non-trainable params
# 806 K     Total params
# 3.226     Total estimated model params size (MB)
# 14        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Epoch 0:  88%|████████▊ | 329/375 [00:05<00:00, 65.30it/s, v_num=2]
# Detected KeyboardInterrupt, attempting graceful shutdown ...
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
# Access human-readable message
if early_stop_callback.stopping_reason_message:
    print(f"Details: {early_stop_callback.stopping_reason_message}")
else:
    print("Early stopping was not triggered.")
# Out:
# Early stopping was not triggered.

# %% [markdown]
# ### Shorten the epoch length

# %%
# use only 10% of training data and 1% of val data
trainer_1 = Trainer(
    limit_train_batches=0.1,
    limit_val_batches=0.1,
    logger=logger,
    callbacks=[checkpoint_callback, early_stop_callback],
    accelerator="gpu",
    devices=1,
    max_epochs=10
)

# use 10 batches of train and 5 batches of val
trainer_2 = Trainer(
    limit_train_batches=10,
    limit_val_batches=5,
    logger=logger,
    callbacks=[checkpoint_callback, early_stop_callback],
    accelerator="gpu",
    devices=1,
    max_epochs=10
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores

# %%
trainer_1.fit(model, train_loader, valid_loader)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
#   | Name    | Type    | Params | Mode  | FLOPs
# ----------------------------------------------------
# 0 | encoder | Encoder | 558 K  | train | 0
# 1 | decoder | Decoder | 247 K  | train | 0
# ----------------------------------------------------
# 806 K     Trainable params
# 0         Non-trainable params
# 806 K     Total params
# 3.226     Total estimated model params size (MB)
# 14        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/pytorch/loops/fit_loop.py:317: The number of training batches (37) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Epoch 9: 100%|██████████| 37/37 [00:00<00:00, 88.23it/s, v_num=0, val_loss=0.0318, train_loss=0.0317]
# `Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100%|██████████| 37/37 [00:00<00:00, 66.12it/s, v_num=0, val_loss=0.0318, train_loss=0.0317]

# %%
trainer_2.fit(model, train_loader, valid_loader)
# Out:
# /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib ...
# /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:881: Checkpoint directory /storage3/DSIP/rriva/tutorials/pl_tutorial/basic/logs/debugging_tests/version_0/checkpoints exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
#   | Name    | Type    | Params | Mode  | FLOPs
# ----------------------------------------------------
# 0 | encoder | Encoder | 558 K  | train | 0
# 1 | decoder | Decoder | 247 K  | train | 0
# ----------------------------------------------------
# 806 K     Trainable params
# 0         Non-trainable params
# 806 K     Total params
# 3.226     Total estimated model params size (MB)
# 14        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/pytorch/loops/fit_loop.py:317: The number of training batches (10) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Epoch 2: 100%|██████████| 10/10 [00:00<00:00, 30.44it/s, v_num=0, val_loss=0.0319, train_loss=0.0313]

# %% [markdown]
# ### Print LightningModule weights summary
# Whenever the `.fit()` function gets called, the Trainer will print the weights summary for the LightningModule.
#
# To add the child modules to the summary add a `ModelSummary`

# %%
from lightning.pytorch.callbacks import ModelSummary

trainer = Trainer(
    callbacks=[ModelSummary(max_depth=-1)],
    accelerator="gpu",
    devices=1,
    max_epochs=10
)
# Out:
# /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib ...
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores

# %%
trainer.fit(model, train_loader, valid_loader)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 trainer.fit(model, train_loader, valid_loader)
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/pytorch/trainer/trainer.py:584, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path, weights_only)
#     582 self.training = True
#     583 self.should_stop = False
# --> 584 call._call_and_handle_interrupt(
#     585     self,
#     586     self._fit_impl,
#     587     model,
#     588     train_dataloaders,
#     589     val_dataloaders,
#     590     datamodule,
#     591     ckpt_path,
#     592     weights_only,
#     593 )
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/pytorch/trainer/call.py:49, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      47     if trainer.strategy.launcher is not None:
#      48         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 49     return trainer_fn(*args, **kwargs)
#      51 except _TunerExitException:
#      52     _call_teardown_hook(trainer)
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/pytorch/trainer/trainer.py:630, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path, weights_only)
#     623     download_model_from_registry(ckpt_path, self)
#     624 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     625     self.state.fn,
#     626     ckpt_path,
#     627     model_provided=True,
#     628     model_connected=self.lightning_module is not None,
#     629 )
# --> 630 self._run(model, ckpt_path=ckpt_path, weights_only=weights_only)
#     632 assert self.state.stopped
#     633 self.training = False
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/pytorch/trainer/trainer.py:1057, in Trainer._run(self, model, ckpt_path, weights_only)
#    1055 # hook
#    1056 if self.state.fn == TrainerFn.FITTING:
# -> 1057     call._call_callback_hooks(self, "on_fit_start")
#    1058     call._call_lightning_module_hook(self, "on_fit_start")
#    1060 # only log hparams if enabled
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/pytorch/trainer/call.py:228, in _call_callback_hooks(trainer, hook_name, monitoring_callbacks, *args, **kwargs)
#     226     if callable(fn):
#     227         with trainer.profiler.profile(f"[Callback]{callback.state_key}.{hook_name}"):
# --> 228             fn(trainer, trainer.lightning_module, *args, **kwargs)
#     230 if pl_module:
#     231     # restore current_fx when nested context
#     232     pl_module._current_fx_name = prev_fx_name
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/pytorch/callbacks/model_summary.py:64, in ModelSummary.on_fit_start(self, trainer, pl_module)
#      61 if not self._max_depth:
#      62     return
# ---> 64 model_summary = self._summary(trainer, pl_module)
#      65 summary_data = model_summary._get_summary_data()
#      66 total_parameters = model_summary.total_parameters
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/pytorch/callbacks/model_summary.py:90, in ModelSummary._summary(self, trainer, pl_module)
#      88 if isinstance(trainer.strategy, DeepSpeedStrategy) and trainer.strategy.zero_stage_3:
#      89     return DeepSpeedSummary(pl_module, max_depth=self._max_depth)
# ---> 90 return summarize(pl_module, max_depth=self._max_depth)
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/model_summary/model_summary.py:565, in summarize(lightning_module, max_depth)
#     552 def summarize(lightning_module: "pl.LightningModule", max_depth: int = 1) -> ModelSummary:
#     553     """Summarize the LightningModule specified by `lightning_module`.
#     554
#     555     Args:
#    (...)    563
#     564     """
# --> 565     return ModelSummary(lightning_module, max_depth=max_depth)
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/model_summary/model_summary.py:228, in ModelSummary.__init__(self, model, max_depth)
#     221 self._flop_counter = FlopCounterMode(
#     222     mods=None if _TORCH_GREATER_EQUAL_2_4 else self._model,
#     223     display=False,
#     224     depth=max_depth + 1,
#     225 )
#     227 self._max_depth = max_depth
# --> 228 self._layer_summary = self.summarize()
#     229 # 1 byte -> 8 bits
#     230 # TODO: how do we compute precision_megabytes in case of mixed precision?
#     231 precision_to_bits = {
#     232     "64": 64,
#     233     "32": 32,
#    (...)    239     "64-true": 64,
#     240 }
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/model_summary/model_summary.py:328, in ModelSummary.summarize(self)
#     326 summary = OrderedDict((name, LayerSummary(module)) for name, module in self.named_modules)
#     327 if self._model.example_input_array is not None:
# --> 328     self._forward_example_input()
#     329 for layer in summary.values():
#     330     layer.detach_hook()
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/model_summary/model_summary.py:371, in ModelSummary._forward_example_input(self)
#     369         model(**input_)
#     370     else:
# --> 371         model(input_)
#     372 mode.restore(model)
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1881, in Module._call_impl(self, *args, **kwargs)
#    1878     return inner()
#    1880 try:
# -> 1881     return inner()
#    1882 except Exception:
#    1883     # run always called hooks if they have not already been run
#    1884     # For now only forward hooks have the always_call option but perhaps
#    1885     # this functionality should be added to full backward hooks as well.
#    1886     for hook_id, hook in _global_forward_hooks.items():
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1829, in Module._call_impl.<locals>.inner()
#    1826     bw_hook = BackwardHook(self, full_backward_hooks, backward_pre_hooks)
#    1827     args = bw_hook.setup_input_hook(args)
# -> 1829 result = forward_call(*args, **kwargs)
#    1830 if _global_forward_hooks or self._forward_hooks:
#    1831     for hook_id, hook in (
#    1832         *_global_forward_hooks.items(),
#    1833         *self._forward_hooks.items(),
#    1834     ):
#    1835         # mark that always called hook is run
#
# Cell In[27], line 67, in LitAutoEncoder.forward(self, x)
#      66 def forward(self, x):
# ---> 67     z = self.encoder(x)
#      68     x_hat = self.decoder(z)
#      69     return x_hat
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1881, in Module._call_impl(self, *args, **kwargs)
#    1878     return inner()
#    1880 try:
# -> 1881     return inner()
#    1882 except Exception:
#    1883     # run always called hooks if they have not already been run
#    1884     # For now only forward hooks have the always_call option but perhaps
#    1885     # this functionality should be added to full backward hooks as well.
#    1886     for hook_id, hook in _global_forward_hooks.items():
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1829, in Module._call_impl.<locals>.inner()
#    1826     bw_hook = BackwardHook(self, full_backward_hooks, backward_pre_hooks)
#    1827     args = bw_hook.setup_input_hook(args)
# -> 1829 result = forward_call(*args, **kwargs)
#    1830 if _global_forward_hooks or self._forward_hooks:
#    1831     for hook_id, hook in (
#    1832         *_global_forward_hooks.items(),
#    1833         *self._forward_hooks.items(),
#    1834     ):
#    1835         # mark that always called hook is run
#
# Cell In[27], line 13, in Encoder.forward(self, x)
#      12 def forward(self, x):
# ---> 13     return self.ff(x)
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1881, in Module._call_impl(self, *args, **kwargs)
#    1878     return inner()
#    1880 try:
# -> 1881     return inner()
#    1882 except Exception:
#    1883     # run always called hooks if they have not already been run
#    1884     # For now only forward hooks have the always_call option but perhaps
#    1885     # this functionality should be added to full backward hooks as well.
#    1886     for hook_id, hook in _global_forward_hooks.items():
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1829, in Module._call_impl.<locals>.inner()
#    1826     bw_hook = BackwardHook(self, full_backward_hooks, backward_pre_hooks)
#    1827     args = bw_hook.setup_input_hook(args)
# -> 1829 result = forward_call(*args, **kwargs)
#    1830 if _global_forward_hooks or self._forward_hooks:
#    1831     for hook_id, hook in (
#    1832         *_global_forward_hooks.items(),
#    1833         *self._forward_hooks.items(),
#    1834     ):
#    1835         # mark that always called hook is run
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     246 """
#     247 Runs the forward pass.
#     248 """
#     249 for module in self:
# --> 250     input = module(input)
#     251 return input
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1881, in Module._call_impl(self, *args, **kwargs)
#    1878     return inner()
#    1880 try:
# -> 1881     return inner()
#    1882 except Exception:
#    1883     # run always called hooks if they have not already been run
#    1884     # For now only forward hooks have the always_call option but perhaps
#    1885     # this functionality should be added to full backward hooks as well.
#    1886     for hook_id, hook in _global_forward_hooks.items():
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1829, in Module._call_impl.<locals>.inner()
#    1826     bw_hook = BackwardHook(self, full_backward_hooks, backward_pre_hooks)
#    1827     args = bw_hook.setup_input_hook(args)
# -> 1829 result = forward_call(*args, **kwargs)
#    1830 if _global_forward_hooks or self._forward_hooks:
#    1831     for hook_id, hook in (
#    1832         *_global_forward_hooks.items(),
#    1833         *self._forward_hooks.items(),
#    1834     ):
#    1835         # mark that always called hook is run
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/torch/nn/modules/linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/torch/utils/flop_counter.py:866, in _FlopCounterMode.__torch_dispatch__(self, func, types, args, kwargs)
#     863             return r
#     865 # no further decomposition; execute & count flops
# --> 866 out = func(*args, **kwargs)
#     867 return self.counter._count_flops(func._overloadpacket, out, args, kwargs)
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/torch/_ops.py:841, in OpOverload.__call__(self, *args, **kwargs)
#     840 def __call__(self, /, *args: _P.args, **kwargs: _P.kwargs) -> _T:
# --> 841     return self._op(*args, **kwargs)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (896x28 and 784x512)
# Epoch 0:   0%|          | 0/10 [15:11<?, ?it/s]
# Epoch 0:   0%|          | 0/10 [02:43<?, ?it/s]

# %% [markdown]
# To print the model summary if `.fit()` is not called:

# %%
model = LitAutoEncoder(Encoder(), Decoder())
summary = ModelSummary(model, max_depth=-1)
print(summary)
# Out:
#    | Name         | Type       | Params | Mode  | FLOPs
# -------------------------------------------------------------
# 0  | encoder      | Encoder    | 54.7 K | train | 0
# 1  | encoder.ff   | Sequential | 54.7 K | train | 0
# 2  | encoder.ff.0 | Linear     | 50.2 K | train | 0
# 3  | encoder.ff.1 | ReLU       | 0      | train | 0
# 4  | encoder.ff.2 | Linear     | 4.2 K  | train | 0
# 5  | encoder.ff.3 | ReLU       | 0      | train | 0
# 6  | encoder.ff.4 | Linear     | 260    | train | 0
# 7  | decoder      | Decoder    | 55.4 K | train | 0
# 8  | decoder.ff   | Sequential | 55.4 K | train | 0
# 9  | decoder.ff.0 | Linear     | 320    | train | 0
# 10 | decoder.ff.1 | ReLU       | 0      | train | 0
# 11 | decoder.ff.2 | Linear     | 4.2 K  | train | 0
# 12 | decoder.ff.3 | ReLU       | 0      | train | 0
# 13 | decoder.ff.4 | Linear     | 51.0 K | train | 0
# -------------------------------------------------------------
# 110 K     Trainable params
# 0         Non-trainable params
# 110 K     Total params
# 0.440     Total estimated model params size (MB)
# 14        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops

# %% [markdown]
# To turn off the autosummary use:

# %%
trainer = Trainer(
    enable_model_summary=False,
    accelerator="gpu",
    devices=1,
    max_epochs=10
)
# Out:
# /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib ...
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores

# %%
trainer.fit(model, train_loader, valid_loader)
# Out:
# /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib ...
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# Epoch 9: 100%|██████████| 375/375 [00:03<00:00, 108.63it/s, v_num=1, val_loss=0.0624, train_loss=0.0628]
# `Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100%|██████████| 375/375 [00:03<00:00, 106.10it/s, v_num=1, val_loss=0.0624, train_loss=0.0628]

# %% [markdown]
# ### Print input output layer dimensions
# Another debugging tool is to display the intermediate input- and output sizes of all your layers by setting the `example_input_array` attribute in your LightningModule.

# %%
class LitModel(LightningModule):
    def __init__(self, *args, **kwargs):
        super().__init__()
        self.example_input_array = torch.Tensor(32, 1, 28, 28)

# %%
model = LitAutoEncoder(
    encoder=Encoder(
        in_dim=28*28,
        hidden_nodes_1=512,
        hidden_nodes_2=256,
        out_dim=100
    ),
    decoder=Decoder(
        in_dim=100,
        hidden_nodes_1=128,
        hidden_nodes_2=256,
        out_dim=28*28
    ),
    example_input_array=torch.Tensor(32, 1, 28*28)
)

# %%
trainer = Trainer(
    callbacks=[ModelSummary(max_depth=-1)],
    accelerator="gpu",
    devices=1,
    max_epochs=10
)
# Out:
# /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib ...
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores

# %%
trainer.fit(model, train_loader, valid_loader)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
#    | Name         | Type       | Params | Mode  | FLOPs  | In sizes     | Out sizes
# --------------------------------------------------------------------------------------------
# 0  | encoder      | Encoder    | 558 K  | train | 35.7 M | [32, 1, 784] | [32, 1, 100]
# 1  | encoder.ff   | Sequential | 558 K  | train | 35.7 M | [32, 1, 784] | [32, 1, 100]
# 2  | encoder.ff.0 | Linear     | 401 K  | train | 25.7 M | [32, 1, 784] | [32, 1, 512]
# 3  | encoder.ff.1 | ReLU       | 0      | train | 0      | [32, 1, 512] | [32, 1, 512]
# 4  | encoder.ff.2 | Linear     | 131 K  | train | 8.4 M  | [32, 1, 512] | [32, 1, 256]
# 5  | encoder.ff.3 | ReLU       | 0      | train | 0      | [32, 1, 256] | [32, 1, 256]
# 6  | encoder.ff.4 | Linear     | 25.7 K | train | 1.6 M  | [32, 1, 256] | [32, 1, 100]
# 7  | decoder      | Decoder    | 247 K  | train | 15.8 M | [32, 1, 100] | [32, 1, 784]
# 8  | decoder.ff   | Sequential | 247 K  | train | 15.8 M | [32, 1, 100] | [32, 1, 784]
# 9  | decoder.ff.0 | Linear     | 12.9 K | train | 819 K  | [32, 1, 100] | [32, 1, 128]
# 10 | decoder.ff.1 | ReLU       | 0      | train | 0      | [32, 1, 128] | [32, 1, 128]
# 11 | decoder.ff.2 | Linear     | 33.0 K | train | 2.1 M  | [32, 1, 128] | [32, 1, 256]
# 12 | decoder.ff.3 | ReLU       | 0      | train | 0      | [32, 1, 256] | [32, 1, 256]
# 13 | decoder.ff.4 | Linear     | 201 K  | train | 12.8 M | [32, 1, 256] | [32, 1, 784]
# --------------------------------------------------------------------------------------------
# 806 K     Trainable params
# 0         Non-trainable params
# 806 K     Total params
# 3.226     Total estimated model params size (MB)
# 14        Modules in train mode
# 0         Modules in eval mode
# 51.5 M    Total Flops
# Epoch 9: 100%|██████████| 375/375 [00:03<00:00, 116.06it/s, v_num=6, val_loss=0.0313, train_loss=0.0321]
# `Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100%|██████████| 375/375 [00:03<00:00, 113.48it/s, v_num=6, val_loss=0.0313, train_loss=0.0321]

# %% [markdown]
# ## Find bottlenecks in your code (basic)
# Profiling helps you find bottlenecks in your code by capturing analytics such as how long a function takes or how much memory is used.

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader, random_split
import torch.nn.functional as F

from lightning import LightningModule
from lightning import Trainer
from lightning.pytorch.callbacks import ModelCheckpoint
from lightning.pytorch.callbacks import EarlyStopping
from lightning.pytorch.callbacks import ModelSummary
from lightning.pytorch.loggers import CSVLogger

from torchvision import datasets
import torchvision.transforms as transforms

import os

# %%
# Load data sets
transform = transforms.ToTensor()
train_set = datasets.MNIST(root="../data/MNIST", download=True, train=True, transform=transform)
test_set = datasets.MNIST(root="../data/MNIST", download=True, train=False, transform=transform)

# use 20% of training data for validation
train_set_size = int(len(train_set) * 0.8)
valid_set_size = len(train_set) - train_set_size

# split the train set into two
seed = torch.Generator().manual_seed(42)
train_set, valid_set = random_split(train_set, [train_set_size, valid_set_size], generator=seed)

train_loader = DataLoader(train_set, batch_size=128, shuffle=True, num_workers=16, persistent_workers=True, pin_memory=True)
valid_loader = DataLoader(valid_set, batch_size=128, num_workers=16, persistent_workers=True, pin_memory=True)
test_loader = DataLoader(test_set, batch_size=1024, num_workers=16, persistent_workers=True, pin_memory=True)

# %%
class Encoder(nn.Module):
    def __init__(self, in_dim=28*28, hidden_nodes_1=64, hidden_nodes_2=64, out_dim=4):
        super().__init__()
        self.ff = nn.Sequential(
            nn.Linear(in_dim, hidden_nodes_1),
            nn.ReLU(),
            nn.Linear(hidden_nodes_1, hidden_nodes_2),
            nn.ReLU(),
            nn.Linear(hidden_nodes_2, out_dim)
        )

    def forward(self, x):
        return self.ff(x)

class Decoder(nn.Module):
    def __init__(self, in_dim=4, hidden_nodes_1=64, hidden_nodes_2=64, out_dim=28*28):
        super().__init__()
        self.ff = nn.Sequential(
            nn.Linear(in_dim, hidden_nodes_1),
            nn.ReLU(),
            nn.Linear(hidden_nodes_1, hidden_nodes_2),
            nn.ReLU(),
            nn.Linear(hidden_nodes_2, out_dim)
        )

    def forward(self, x):
        return self.ff(x)

class LitAutoEncoder(LightningModule):
    def __init__(self, encoder, decoder, lr=1e-5, example_input_array=None):
        super().__init__()
        self.example_input_array = example_input_array
        self.encoder = encoder
        self.decoder = decoder
        self.lr = lr
        self.save_hyperparameters(ignore=["encoder", "decoder"])

    def training_step(self, batch, batch_idx):
        # training_step defines the train loop.
        loss = self._get_loss(batch)
        self.log("train/loss", loss, on_step=True, on_epoch=True)
        self.log("train_loss", loss, prog_bar=True, on_step=False, on_epoch=True)
        return loss

    def validation_step(self, batch, batch_idx):
        # this is the validation loop
        loss = self._get_loss(batch)
        self.log("val_loss", loss, prog_bar=True)

    def test_step(self, batch, batch_idx):
        # this is the test loop
        loss = self._get_loss(batch)
        self.log("test_loss", loss)

    def _get_loss(self, batch):
        x, _ = batch
        x = x.view(x.size(0), -1)
        x_hat = self.forward(x)
        loss = F.mse_loss(x_hat, x)
        return loss

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=self.lr)
        return optimizer

    def forward(self, x):
        z = self.encoder(x)
        x_hat = self.decoder(z)
        return x_hat

# %%
model = LitAutoEncoder(
    encoder=Encoder(
        in_dim=28*28,
        hidden_nodes_1=512,
        hidden_nodes_2=256,
        out_dim=100
    ),
    decoder=Decoder(
        in_dim=100,
        hidden_nodes_1=128,
        hidden_nodes_2=256,
        out_dim=28*28
    ),
    example_input_array=torch.Tensor(32, 1, 28*28)
)

# %%
logger = CSVLogger(
    save_dir='logs',
    name='find_bottlenecks',
    version=None
)

checkpoint_callback = ModelCheckpoint(
    dirpath=os.path.join(logger.log_dir, "checkpoints"),
    filename="autoencoder_best-{epoch:02d}-{val_loss:.3f}",
    monitor="val_loss",    
    mode="min",
    save_top_k=3,     # keep ONLY the best
    save_last=True    # ALSO save last.ckpt
)

early_stop_callback = EarlyStopping(
    monitor="val_loss",
    patience=3,
    verbose=False,
    mode="min"
)

model_summary = ModelSummary(-1)
print(model_summary)
# Out:
# <lightning.pytorch.callbacks.model_summary.ModelSummary object at 0x7fa33e1cf380>

# %%
from lightning.pytorch.callbacks import ModelSummary as MS_Callback
from lightning.pytorch.utilities.model_summary import ModelSummary

# %%
model_summary_callback = MS_Callback(max_depth=-1)
model_summary = ModelSummary(model,-1)
print(model_summary)
print(model_summary_callback)
# Out:
#    | Name         | Type       | Params | Mode  | FLOPs  | In sizes     | Out sizes
# --------------------------------------------------------------------------------------------
# 0  | encoder      | Encoder    | 558 K  | train | 35.7 M | [32, 1, 784] | [32, 1, 100]
# 1  | encoder.ff   | Sequential | 558 K  | train | 35.7 M | [32, 1, 784] | [32, 1, 100]
# 2  | encoder.ff.0 | Linear     | 401 K  | train | 25.7 M | [32, 1, 784] | [32, 1, 512]
# 3  | encoder.ff.1 | ReLU       | 0      | train | 0      | [32, 1, 512] | [32, 1, 512]
# 4  | encoder.ff.2 | Linear     | 131 K  | train | 8.4 M  | [32, 1, 512] | [32, 1, 256]
# 5  | encoder.ff.3 | ReLU       | 0      | train | 0      | [32, 1, 256] | [32, 1, 256]
# 6  | encoder.ff.4 | Linear     | 25.7 K | train | 1.6 M  | [32, 1, 256] | [32, 1, 100]
# 7  | decoder      | Decoder    | 247 K  | train | 15.8 M | [32, 1, 100] | [32, 1, 784]
# 8  | decoder.ff   | Sequential | 247 K  | train | 15.8 M | [32, 1, 100] | [32, 1, 784]
# 9  | decoder.ff.0 | Linear     | 12.9 K | train | 819 K  | [32, 1, 100] | [32, 1, 128]
# 10 | decoder.ff.1 | ReLU       | 0      | train | 0      | [32, 1, 128] | [32, 1, 128]
# 11 | decoder.ff.2 | Linear     | 33.0 K | train | 2.1 M  | [32, 1, 128] | [32, 1, 256]
# 12 | decoder.ff.3 | ReLU       | 0      | train | 0      | [32, 1, 256] | [32, 1, 256]
# 13 | decoder.ff.4 | Linear     | 201 K  | train | 12.8 M | [32, 1, 256] | [32, 1, 784]
# --------------------------------------------------------------------------------------------
# 806 K     Trainable params
# 0         Non-trainable params
# 806 K     Total params
# 3.226     Total estimated model params size (MB)
# 14        Modules in train mode
# 0         Modules in eval mode
# 51.5 M    Total Flops
# <lightning.pytorch.callbacks.model_summary.ModelSummary object at 0x7fa33e1ab390>

# %% [markdown]
# ### Find training loop bottlenecks
# The most basic profile measures all the key methods across Callbacks, DataModules and the LightningModule in the training loop.
#
# ```
# trainer = Trainer(profiler="simple")
# ```

# %%
trainer = Trainer(
    profiler='simple',
    logger=logger,
    callbacks=[checkpoint_callback, early_stop_callback, model_summary_callback],
    accelerator="gpu",
    devices=1,
    max_epochs=100
)
# Out:
# /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib ...
# Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores

# %%
trainer.fit(model, train_loader, valid_loader)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
#    | Name         | Type       | Params | Mode  | FLOPs  | In sizes     | Out sizes
# --------------------------------------------------------------------------------------------
# 0  | encoder      | Encoder    | 558 K  | train | 35.7 M | [32, 1, 784] | [32, 1, 100]
# 1  | encoder.ff   | Sequential | 558 K  | train | 35.7 M | [32, 1, 784] | [32, 1, 100]
# 2  | encoder.ff.0 | Linear     | 401 K  | train | 25.7 M | [32, 1, 784] | [32, 1, 512]
# 3  | encoder.ff.1 | ReLU       | 0      | train | 0      | [32, 1, 512] | [32, 1, 512]
# 4  | encoder.ff.2 | Linear     | 131 K  | train | 8.4 M  | [32, 1, 512] | [32, 1, 256]
# 5  | encoder.ff.3 | ReLU       | 0      | train | 0      | [32, 1, 256] | [32, 1, 256]
# 6  | encoder.ff.4 | Linear     | 25.7 K | train | 1.6 M  | [32, 1, 256] | [32, 1, 100]
# 7  | decoder      | Decoder    | 247 K  | train | 15.8 M | [32, 1, 100] | [32, 1, 784]
# 8  | decoder.ff   | Sequential | 247 K  | train | 15.8 M | [32, 1, 100] | [32, 1, 784]
# 9  | decoder.ff.0 | Linear     | 12.9 K | train | 819 K  | [32, 1, 100] | [32, 1, 128]
# 10 | decoder.ff.1 | ReLU       | 0      | train | 0      | [32, 1, 128] | [32, 1, 128]
# 11 | decoder.ff.2 | Linear     | 33.0 K | train | 2.1 M  | [32, 1, 128] | [32, 1, 256]
# 12 | decoder.ff.3 | ReLU       | 0      | train | 0      | [32, 1, 256] | [32, 1, 256]
# 13 | decoder.ff.4 | Linear     | 201 K  | train | 12.8 M | [32, 1, 256] | [32, 1, 784]
# --------------------------------------------------------------------------------------------
# 806 K     Trainable params
# 0         Non-trainable params
# 806 K     Total params
# 3.226     Total estimated model params size (MB)
# 14        Modules in train mode
# 0         Modules in eval mode
# 51.5 M    Total Flops
# Epoch 99: 100%|██████████| 375/375 [00:03<00:00, 108.79it/s, v_num=4, val_loss=0.0107, train_loss=0.0107]
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Epoch 99: 100%|██████████| 375/375 [00:03<00:00, 104.29it/s, v_num=4, val_loss=0.0107, train_loss=0.0107]
# FIT Profiler Report
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                               	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                                	|  -              	|  1730200        	|  352.32         	|  100 %          	|
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  run_training_epoch                                                                                                                                                   	|  3.3545         	|  100            	|  335.45         	|  95.212         	|
# |  run_training_batch                                                                                                                                                   	|  0.0049516      	|  37500          	|  185.69         	|  52.704         	|
# |  [LightningModule]LitAutoEncoder.optimizer_step                                                                                                                       	|  0.0048626      	|  37500          	|  182.35         	|  51.756         	|
# |  [Strategy]SingleDeviceStrategy.training_step                                                                                                                         	|  0.0022192      	|  37500          	|  83.22          	|  23.621         	|
# |  [Callback]TQDMProgressBar.on_train_batch_end                                                                                                                         	|  0.0015157      	|  37500          	|  56.84          	|  16.133         	|
# |  [Strategy]SingleDeviceStrategy.backward                                                                                                                              	|  0.0013924      	|  37500          	|  52.214         	|  14.82          	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                                       	|  0.00035173     	|  46902          	|  16.497         	|  4.6823         	|
# |  [Callback]TQDMProgressBar.on_validation_batch_end                                                                                                                    	|  0.001723       	|  9402           	|  16.2           	|  4.5981         	|
# |  [Strategy]SingleDeviceStrategy.validation_step                                                                                                                       	|  0.0016941      	|  9402           	|  15.928         	|  4.5209         	|
# |  [LightningModule]LitAutoEncoder.transfer_batch_to_device                                                                                                             	|  0.00030852     	|  46903          	|  14.471         	|  4.1072         	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_epoch_end       	|  0.13986        	|  100            	|  13.986         	|  3.9698         	|
# |  save_checkpoint                                                                                                                                                      	|  0.061703       	|  200            	|  12.341         	|  3.5027         	|
# |  [_TrainingEpochLoop].train_dataloader_next                                                                                                                           	|  0.00024894     	|  37500          	|  9.3351         	|  2.6496         	|
# |  [LightningModule]LitAutoEncoder.optimizer_zero_grad                                                                                                                  	|  0.00013006     	|  37500          	|  4.8774         	|  1.3844         	|
# |  [_EvaluationLoop].val_next                                                                                                                                           	|  0.00050434     	|  9402           	|  4.7418         	|  1.3459         	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_epoch_end                                                                                     	|  0.008281       	|  100            	|  0.8281         	|  0.23504        	|
# |  [LightningModule]LitAutoEncoder.configure_gradient_clipping                                                                                                          	|  1.8422e-05     	|  37500          	|  0.69084        	|  0.19608        	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_batch_end       	|  1.6456e-05     	|  37500          	|  0.61708        	|  0.17515        	|
# |  [Callback]TQDMProgressBar.on_validation_batch_start                                                                                                                  	|  4.3623e-05     	|  9402           	|  0.41014        	|  0.11641        	|
# |  [Callback]TQDMProgressBar.on_validation_start                                                                                                                        	|  0.0040175      	|  101            	|  0.40576        	|  0.11517        	|
# |  [Callback]TQDMProgressBar.on_train_epoch_end                                                                                                                         	|  0.0023567      	|  100            	|  0.23567        	|  0.066892       	|
# |  [Callback]TQDMProgressBar.on_validation_end                                                                                                                          	|  0.0022804      	|  101            	|  0.23032        	|  0.065372       	|
# |  [Callback]TQDMProgressBar.on_train_epoch_start                                                                                                                       	|  0.0013405      	|  100            	|  0.13405        	|  0.038049       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_zero_grad                                                                                    	|  3.1387e-06     	|  37500          	|  0.1177         	|  0.033408       	|
# |  [Callback]ModelSummary.on_fit_start                                                                                                                                  	|  0.10925        	|  1              	|  0.10925        	|  0.031009       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_batch_end                                                                                     	|  2.891e-06      	|  37500          	|  0.10841        	|  0.030771       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_after_backward                                                                                      	|  2.2998e-06     	|  37500          	|  0.086242       	|  0.024479       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_batch_start                                                                                   	|  2.0455e-06     	|  37500          	|  0.076705       	|  0.021772       	|
# |  [LightningModule]LitAutoEncoder.on_before_batch_transfer                                                                                                             	|  1.5152e-06     	|  46903          	|  0.071069       	|  0.020172       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_backward                                                                                     	|  1.8798e-06     	|  37500          	|  0.070494       	|  0.020009       	|
# |  [Callback]ModelSummary.on_after_backward                                                                                                                             	|  1.8372e-06     	|  37500          	|  0.068896       	|  0.019555       	|
# |  [Callback]ModelSummary.on_train_batch_start                                                                                                                          	|  1.4402e-06     	|  37500          	|  0.054008       	|  0.015329       	|
# |  [Callback]ModelSummary.on_before_zero_grad                                                                                                                           	|  1.4362e-06     	|  37500          	|  0.053858       	|  0.015287       	|
# |  [Callback]ModelSummary.on_train_batch_end                                                                                                                            	|  1.3669e-06     	|  37500          	|  0.051257       	|  0.014548       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_optimizer_step                                                                               	|  1.3107e-06     	|  37500          	|  0.049151       	|  0.013951       	|
# |  [LightningModule]LitAutoEncoder.on_after_batch_transfer                                                                                                              	|  1.031e-06      	|  46903          	|  0.048356       	|  0.013725       	|
# |  [Callback]TQDMProgressBar.on_before_optimizer_step                                                                                                                   	|  1.233e-06      	|  37500          	|  0.046237       	|  0.013124       	|
# |  [LightningModule]LitAutoEncoder.on_train_batch_end                                                                                                                   	|  1.1886e-06     	|  37500          	|  0.044572       	|  0.012651       	|
# |  [Callback]TQDMProgressBar.on_before_zero_grad                                                                                                                        	|  1.0783e-06     	|  37500          	|  0.040438       	|  0.011478       	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_zero_grad      	|  1.0113e-06     	|  37500          	|  0.037923       	|  0.010764       	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_batch_start     	|  9.7921e-07     	|  37500          	|  0.03672        	|  0.010422       	|
# |  [Callback]ModelSummary.on_before_backward                                                                                                                            	|  9.5344e-07     	|  37500          	|  0.035754       	|  0.010148       	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_backward       	|  9.3833e-07     	|  37500          	|  0.035188       	|  0.0099874      	|
# |  [Callback]TQDMProgressBar.on_before_backward                                                                                                                         	|  9.3764e-07     	|  37500          	|  0.035161       	|  0.00998        	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_optimizer_step 	|  9.1897e-07     	|  37500          	|  0.034462       	|  0.0097814      	|
# |  [Callback]TQDMProgressBar.on_train_batch_start                                                                                                                       	|  9.1295e-07     	|  37500          	|  0.034236       	|  0.0097173      	|
# |  [Callback]ModelSummary.on_before_optimizer_step                                                                                                                      	|  9.0819e-07     	|  37500          	|  0.034057       	|  0.0096666      	|
# |  [LightningModule]LitAutoEncoder.on_before_zero_grad                                                                                                                  	|  9.0688e-07     	|  37500          	|  0.034008       	|  0.0096526      	|
# |  [Callback]TQDMProgressBar.on_after_backward                                                                                                                          	|  9.0082e-07     	|  37500          	|  0.033781       	|  0.0095881      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_after_backward        	|  8.8384e-07     	|  37500          	|  0.033144       	|  0.0094074      	|
# |  [LightningModule]LitAutoEncoder.on_after_backward                                                                                                                    	|  8.3607e-07     	|  37500          	|  0.031353       	|  0.0088989      	|
# |  [Strategy]SingleDeviceStrategy.on_train_batch_start                                                                                                                  	|  8.0894e-07     	|  37500          	|  0.030335       	|  0.0086102      	|
# |  [LightningModule]LitAutoEncoder.on_before_optimizer_step                                                                                                             	|  7.8971e-07     	|  37500          	|  0.029614       	|  0.0084055      	|
# |  [LightningModule]LitAutoEncoder.on_train_batch_start                                                                                                                 	|  7.8808e-07     	|  37500          	|  0.029553       	|  0.0083882      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_batch_end                                                                                	|  2.982e-06      	|  9402           	|  0.028037       	|  0.0079579      	|
# |  [LightningModule]LitAutoEncoder.on_before_backward                                                                                                                   	|  7.3073e-07     	|  37500          	|  0.027403       	|  0.0077778      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_batch_end  	|  2.5331e-06     	|  9402           	|  0.023816       	|  0.0067599      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_batch_start                                                                              	|  2.2086e-06     	|  9402           	|  0.020765       	|  0.0058938      	|
# |  [Callback]ModelSummary.on_validation_batch_end                                                                                                                       	|  1.6401e-06     	|  9402           	|  0.015421       	|  0.0043769      	|
# |  [LightningModule]LitAutoEncoder.on_validation_model_zero_grad                                                                                                        	|  0.00014039     	|  100            	|  0.014039       	|  0.0039848      	|
# |  [LightningModule]LitAutoEncoder.on_validation_batch_end                                                                                                              	|  1.2622e-06     	|  9402           	|  0.011867       	|  0.0033684      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_batch_start	|  1.2098e-06     	|  9402           	|  0.011375       	|  0.0032285      	|
# |  [Callback]ModelSummary.on_validation_batch_start                                                                                                                     	|  1.149e-06      	|  9402           	|  0.010803       	|  0.0030663      	|
# |  [LightningModule]LitAutoEncoder.on_validation_batch_start                                                                                                            	|  1.0846e-06     	|  9402           	|  0.010198       	|  0.0028945      	|
# |  [LightningModule]LitAutoEncoder.on_validation_model_eval                                                                                                             	|  8.7179e-05     	|  101            	|  0.0088051      	|  0.0024992      	|
# |  [Callback]TQDMProgressBar.on_train_start                                                                                                                             	|  0.0049106      	|  1              	|  0.0049106      	|  0.0013938      	|
# |  [Callback]TQDMProgressBar.on_sanity_check_start                                                                                                                      	|  0.0038603      	|  1              	|  0.0038603      	|  0.0010957      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_end        	|  3.0385e-05     	|  101            	|  0.0030689      	|  0.00087106     	|
# |  [Callback]TQDMProgressBar.on_train_end                                                                                                                               	|  0.00058048     	|  1              	|  0.00058048     	|  0.00016476     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.setup                    	|  0.00040171     	|  1              	|  0.00040171     	|  0.00011402     	|
# |  [LightningModule]LitAutoEncoder.configure_optimizers                                                                                                                 	|  0.00034009     	|  1              	|  0.00034009     	|  9.6528e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_save_checkpoint                                                                                     	|  1.5857e-06     	|  200            	|  0.00031715     	|  9.0018e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_end                                                                                      	|  2.8336e-06     	|  101            	|  0.0002862      	|  8.1232e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_start                                                                                    	|  2.6361e-06     	|  101            	|  0.00026625     	|  7.557e-05      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_epoch_end                                                                                	|  2.6202e-06     	|  101            	|  0.00026464     	|  7.5115e-05     	|
# |  [Callback]ModelSummary.on_train_epoch_end                                                                                                                            	|  2.4043e-06     	|  100            	|  0.00024043     	|  6.8242e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_start      	|  2.378e-06      	|  101            	|  0.00024018     	|  6.8171e-05     	|
# |  [Callback]ModelSummary.on_save_checkpoint                                                                                                                            	|  1.15e-06       	|  200            	|  0.00023        	|  6.5281e-05     	|
# |  [LightningModule]LitAutoEncoder.on_train_epoch_end                                                                                                                   	|  1.8018e-06     	|  100            	|  0.00018018     	|  5.1143e-05     	|
# |  [Callback]ModelSummary.on_validation_epoch_end                                                                                                                       	|  1.7563e-06     	|  101            	|  0.00017738     	|  5.0347e-05     	|
# |  [LightningModule]LitAutoEncoder.on_save_checkpoint                                                                                                                   	|  8.5151e-07     	|  200            	|  0.0001703      	|  4.8337e-05     	|
# |  [LightningModule]LitAutoEncoder.on_validation_end                                                                                                                    	|  1.6763e-06     	|  101            	|  0.00016931     	|  4.8055e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_epoch_start                                                                                   	|  1.6642e-06     	|  100            	|  0.00016642     	|  4.7237e-05     	|
# |  [Callback]TQDMProgressBar.on_save_checkpoint                                                                                                                         	|  8.1807e-07     	|  200            	|  0.00016361     	|  4.6439e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_save_checkpoint       	|  7.9855e-07     	|  200            	|  0.00015971     	|  4.5331e-05     	|
# |  [LightningModule]LitAutoEncoder.on_validation_start                                                                                                                  	|  1.5697e-06     	|  101            	|  0.00015854     	|  4.4998e-05     	|
# |  [Callback]ModelSummary.on_validation_end                                                                                                                             	|  1.5498e-06     	|  101            	|  0.00015653     	|  4.4429e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_epoch_start                                                                              	|  1.5362e-06     	|  101            	|  0.00015516     	|  4.4039e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_end                                                                                                                     	|  1.0687e-06     	|  101            	|  0.00010794     	|  3.0636e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_epoch_start     	|  1.0688e-06     	|  100            	|  0.00010688     	|  3.0337e-05     	|
# |  [LightningModule]LitAutoEncoder.on_validation_epoch_end                                                                                                              	|  1.0578e-06     	|  101            	|  0.00010684     	|  3.0324e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_epoch_end  	|  1.0399e-06     	|  101            	|  0.00010503     	|  2.9812e-05     	|
# |  [Callback]ModelSummary.on_validation_start                                                                                                                           	|  1.013e-06      	|  101            	|  0.00010232     	|  2.9041e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_start                                                                                                                   	|  1.0111e-06     	|  101            	|  0.00010212     	|  2.8986e-05     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_end                                                                                                                    	|  1.0034e-06     	|  101            	|  0.00010134     	|  2.8763e-05     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_start                                                                                                                  	|  9.9314e-07     	|  101            	|  0.00010031     	|  2.8471e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_epoch_start	|  9.8753e-07     	|  101            	|  9.9741e-05     	|  2.831e-05      	|
# |  [Callback]ModelSummary.on_validation_epoch_start                                                                                                                     	|  9.3826e-07     	|  101            	|  9.4764e-05     	|  2.6897e-05     	|
# |  [LightningModule]LitAutoEncoder.on_validation_epoch_start                                                                                                            	|  8.5626e-07     	|  101            	|  8.6483e-05     	|  2.4547e-05     	|
# |  [LightningModule]LitAutoEncoder.on_train_epoch_start                                                                                                                 	|  7.2833e-07     	|  100            	|  7.2833e-05     	|  2.0673e-05     	|
# |  [Callback]ModelSummary.on_train_epoch_start                                                                                                                          	|  5.8789e-07     	|  100            	|  5.8789e-05     	|  1.6686e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_start           	|  1.0911e-05     	|  1              	|  1.0911e-05     	|  3.097e-06      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_start                                                                                         	|  9.6001e-06     	|  1              	|  9.6001e-06     	|  2.7248e-06     	|
# |  [Callback]TQDMProgressBar.on_sanity_check_end                                                                                                                        	|  7.6927e-06     	|  1              	|  7.6927e-06     	|  2.1835e-06     	|
# |  [LightningModule]LitAutoEncoder.on_train_start                                                                                                                       	|  5.3197e-06     	|  1              	|  5.3197e-06     	|  1.5099e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_train_start                                                                                                                        	|  5.2117e-06     	|  1              	|  5.2117e-06     	|  1.4793e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.setup                                                                                                  	|  5.1595e-06     	|  1              	|  5.1595e-06     	|  1.4644e-06     	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                                      	|  4.6603e-06     	|  1              	|  4.6603e-06     	|  1.3228e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_fit_end                                                                                             	|  3.6396e-06     	|  1              	|  3.6396e-06     	|  1.033e-06      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_fit_start                                                                                           	|  3.0808e-06     	|  1              	|  3.0808e-06     	|  8.7444e-07     	|
# |  [LightningModule]LitAutoEncoder.setup                                                                                                                                	|  2.7604e-06     	|  1              	|  2.7604e-06     	|  7.8351e-07     	|
# |  [LightningModule]LitAutoEncoder.configure_callbacks                                                                                                                  	|  2.7195e-06     	|  1              	|  2.7195e-06     	|  7.7188e-07     	|
# |  [Callback]ModelSummary.setup                                                                                                                                         	|  2.671e-06      	|  1              	|  2.671e-06      	|  7.5813e-07     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.teardown                                                                                               	|  2.5406e-06     	|  1              	|  2.5406e-06     	|  7.2112e-07     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_end                                                                                           	|  2.4512e-06     	|  1              	|  2.4512e-06     	|  6.9575e-07     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_sanity_check_start                                                                                  	|  2.2575e-06     	|  1              	|  2.2575e-06     	|  6.4076e-07     	|
# |  [Callback]ModelSummary.on_fit_end                                                                                                                                    	|  2.2091e-06     	|  1              	|  2.2091e-06     	|  6.2702e-07     	|
# |  [Callback]TQDMProgressBar.on_fit_start                                                                                                                               	|  2.1197e-06     	|  1              	|  2.1197e-06     	|  6.0164e-07     	|
# |  [Callback]ModelSummary.teardown                                                                                                                                      	|  2.0489e-06     	|  1              	|  2.0489e-06     	|  5.8155e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_end             	|  1.8179e-06     	|  1              	|  1.8179e-06     	|  5.1599e-07     	|
# |  [LightningModule]LitAutoEncoder.teardown                                                                                                                             	|  1.5534e-06     	|  1              	|  1.5534e-06     	|  4.4092e-07     	|
# |  [Callback]TQDMProgressBar.on_fit_end                                                                                                                                 	|  1.4305e-06     	|  1              	|  1.4305e-06     	|  4.0603e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_end               	|  1.289e-06      	|  1              	|  1.289e-06      	|  3.6585e-07     	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                                   	|  1.2331e-06     	|  1              	|  1.2331e-06     	|  3.4999e-07     	|
# |  [LightningModule]LitAutoEncoder.on_fit_end                                                                                                                           	|  1.1586e-06     	|  1              	|  1.1586e-06     	|  3.2884e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.teardown                 	|  1.1586e-06     	|  1              	|  1.1586e-06     	|  3.2884e-07     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_sanity_check_end                                                                                    	|  1.0617e-06     	|  1              	|  1.0617e-06     	|  3.0135e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_sanity_check_start    	|  9.574e-07      	|  1              	|  9.574e-07      	|  2.7174e-07     	|
# |  [Callback]ModelSummary.on_train_start                                                                                                                                	|  7.5251e-07     	|  1              	|  7.5251e-07     	|  2.1359e-07     	|
# |  [Callback]ModelSummary.on_sanity_check_start                                                                                                                         	|  7.0781e-07     	|  1              	|  7.0781e-07     	|  2.009e-07      	|
# |  [LightningModule]LitAutoEncoder.on_fit_start                                                                                                                         	|  6.5193e-07     	|  1              	|  6.5193e-07     	|  1.8504e-07     	|
# |  [Strategy]SingleDeviceStrategy.on_train_end                                                                                                                          	|  6.333e-07      	|  1              	|  6.333e-07      	|  1.7975e-07     	|
# |  [LightningModule]LitAutoEncoder.on_train_end                                                                                                                         	|  6.2957e-07     	|  1              	|  6.2957e-07     	|  1.7869e-07     	|
# |  [Callback]ModelSummary.on_sanity_check_end                                                                                                                           	|  5.6997e-07     	|  1              	|  5.6997e-07     	|  1.6178e-07     	|
# |  [Callback]ModelSummary.on_train_end                                                                                                                                  	|  5.6997e-07     	|  1              	|  5.6997e-07     	|  1.6178e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_start             	|  4.5076e-07     	|  1              	|  4.5076e-07     	|  1.2794e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_sanity_check_end      	|  3.9861e-07     	|  1              	|  3.9861e-07     	|  1.1314e-07     	|
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Profile the time within every function
# `trainer = Trainer(profiler="advanced")`

# %%
trainer = Trainer(
    profiler='advanced',
    logger=logger,
    callbacks=[checkpoint_callback, early_stop_callback, model_summary_callback],
    accelerator="gpu",
    devices=1,
    max_epochs=10
)
# Out:
# Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores

# %%
trainer.fit(model, train_loader, valid_loader)
# Out:
# /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:881: Checkpoint directory /storage3/DSIP/rriva/tutorials/pl_tutorial/basic/logs/find_bottlenecks/version_4/checkpoints exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
#    | Name         | Type       | Params | Mode  | FLOPs  | In sizes     | Out sizes
# --------------------------------------------------------------------------------------------
# 0  | encoder      | Encoder    | 558 K  | train | 35.7 M | [32, 1, 784] | [32, 1, 100]
# 1  | encoder.ff   | Sequential | 558 K  | train | 35.7 M | [32, 1, 784] | [32, 1, 100]
# 2  | encoder.ff.0 | Linear     | 401 K  | train | 25.7 M | [32, 1, 784] | [32, 1, 512]
# 3  | encoder.ff.1 | ReLU       | 0      | train | 0      | [32, 1, 512] | [32, 1, 512]
# 4  | encoder.ff.2 | Linear     | 131 K  | train | 8.4 M  | [32, 1, 512] | [32, 1, 256]
# 5  | encoder.ff.3 | ReLU       | 0      | train | 0      | [32, 1, 256] | [32, 1, 256]
# 6  | encoder.ff.4 | Linear     | 25.7 K | train | 1.6 M  | [32, 1, 256] | [32, 1, 100]
# 7  | decoder      | Decoder    | 247 K  | train | 15.8 M | [32, 1, 100] | [32, 1, 784]
# 8  | decoder.ff   | Sequential | 247 K  | train | 15.8 M | [32, 1, 100] | [32, 1, 784]
# 9  | decoder.ff.0 | Linear     | 12.9 K | train | 819 K  | [32, 1, 100] | [32, 1, 128]
# 10 | decoder.ff.1 | ReLU       | 0      | train | 0      | [32, 1, 128] | [32, 1, 128]
# 11 | decoder.ff.2 | Linear     | 33.0 K | train | 2.1 M  | [32, 1, 128] | [32, 1, 256]
# 12 | decoder.ff.3 | ReLU       | 0      | train | 0      | [32, 1, 256] | [32, 1, 256]
# 13 | decoder.ff.4 | Linear     | 201 K  | train | 12.8 M | [32, 1, 256] | [32, 1, 784]
# --------------------------------------------------------------------------------------------
# 806 K     Trainable params
# 0         Non-trainable params
# 806 K     Total params
# 3.226     Total estimated model params size (MB)
# 14        Modules in train mode
# 0         Modules in eval mode
# 51.5 M    Total Flops
# Epoch 9: 100%|██████████| 375/375 [00:06<00:00, 58.08it/s, v_num=4, val_loss=0.0102, train_loss=0.0102]
# `Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100%|██████████| 375/375 [00:06<00:00, 56.73it/s, v_num=4, val_loss=0.0102, train_loss=0.0102]
# FIT Profiler Report
# Profile stats for: [LightningModule]LitAutoEncoder.configure_callbacks
#          7 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:56(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:81(stop)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 module.py:970(configure_callbacks)
#
#
#
# Profile stats for: [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.setup
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:56(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:81(stop)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1271(lightning_module)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 early_stopping.py:157(setup)
#         1    0.000    0.000    0.000    0.000 trainer.py:1218(strategy)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#
#
#
# Profile stats for: [Callback]ModelSummary.setup
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:56(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:81(stop)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1271(lightning_module)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1218(strategy)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         1    0.000    0.000    0.000    0.000 callback.py:58(setup)
#
#
#
# Profile stats for: [Callback]TQDMProgressBar.setup
#          13 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:56(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:81(stop)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 progress_bar.py:174(setup)
#         1    0.000    0.000    0.000    0.000 trainer.py:1271(lightning_module)
#         1    0.000    0.000    0.000    0.000 trainer.py:1334(is_global_zero)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 trainer.py:1218(strategy)
#         1    0.000    0.000    0.000    0.000 single_device.py:81(is_global_zero)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#
#
#
# Profile stats for: [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.setup
#          251 function calls in 0.002 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.002    0.002 model_checkpoint.py:322(setup)
#         1    0.000    0.000    0.002    0.002 model_checkpoint.py:879(__warn_if_dir_not_empty)
#         1    0.000    0.000    0.001    0.001 cloud_io.py:134(_is_dir)
#         1    0.000    0.000    0.001    0.001 local.py:148(isdir)
#         2    0.001    0.000    0.001    0.000 {built-in method posix.stat}
#         1    0.000    0.000    0.001    0.001 <frozen genericpath>:48(isdir)
#         1    0.000    0.000    0.001    0.001 local.py:59(ls)
#         1    0.000    0.000    0.000    0.000 rank_zero.py:35(wrapped_fn)
#         1    0.000    0.000    0.000    0.000 rank_zero.py:73(rank_zero_warn)
#         1    0.000    0.000    0.000    0.000 rank_zero.py:69(_warn)
#         1    0.000    0.000    0.000    0.000 {built-in method _warnings.warn}
#         1    0.000    0.000    0.000    0.000 warnings.py:97(_showwarnmsg)
#         1    0.000    0.000    0.000    0.000 warnings.py:20(_showwarnmsg_impl)
#         1    0.000    0.000    0.000    0.000 cloud_io.py:80(get_filesystem)
#         1    0.000    0.000    0.000    0.000 core.py:386(url_to_fs)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.scandir}
#         1    0.000    0.000    0.000    0.000 warnings.py:118(_formatwarnmsg)
#         1    0.000    0.000    0.000    0.000 warnings.py:40(_custom_format_warning)
#         1    0.000    0.000    0.000    0.000 interactiveshell.py:3051(write)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:56(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:81(stop)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 iostream.py:650(write)
#         1    0.000    0.000    0.000    0.000 warnings.py:57(_is_path_in_lightning)
#         1    0.000    0.000    0.000    0.000 _local.py:227(__str__)
#         1    0.000    0.000    0.000    0.000 core.py:331(_un_chain)
#         1    0.000    0.000    0.000    0.000 registry.py:311(filesystem)
#         8    0.000    0.000    0.000    0.000 local.py:249(_strip_protocol)
#         1    0.000    0.000    0.000    0.000 _local.py:289(drive)
#         1    0.000    0.000    0.000    0.000 spec.py:65(__call__)
#         1    0.000    0.000    0.000    0.000 iostream.py:572(_schedule_flush)
#         1    0.000    0.000    0.000    0.000 iostream.py:260(schedule)
#         1    0.000    0.000    0.000    0.000 _local.py:257(_parse_path)
#         1    0.000    0.000    0.000    0.000 local.py:78(info)
#         1    0.000    0.000    0.000    0.000 socket.py:623(send)
#         1    0.000    0.000    0.000    0.000 utils.py:299(tokenize)
#        13    0.000    0.000    0.000    0.000 {built-in method sys.intern}
#         1    0.000    0.000    0.000    0.000 _local.py:498(__init__)
#         8    0.000    0.000    0.000    0.000 local.py:299(make_path_posix)
#        10    0.000    0.000    0.000    0.000 utils.py:320(stringify_path)
#         1    0.000    0.000    0.000    0.000 enums.py:81(__eq__)
#        42    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 cloud_io.py:112(_is_object_storage)
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         2    0.000    0.000    0.000    0.000 registry.py:244(get_filesystem_class)
#         1    0.000    0.000    0.000    0.000 threading.py:1136(is_alive)
#         1    0.000    0.000    0.000    0.000 _local.py:505(__new__)
#         1    0.000    0.000    0.000    0.000 _local.py:117(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#        24    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 config.py:99(apply_config)
#         1    0.000    0.000    0.000    0.000 core.py:565(split_protocol)
#         1    0.000    0.000    0.000    0.000 {built-in method _hashlib.openssl_md5}
#         1    0.000    0.000    0.000    0.000 _local.py:634(absolute)
#         1    0.000    0.000    0.000    0.000 _local.py:237(_format_parsed_parts)
#         1    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         1    0.000    0.000    0.000    0.000 {built-in method posix._path_splitroot_ex}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 iostream.py:510(parent_header)
#         8    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 iostream.py:545(_is_master_process)
#         1    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         8    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 _local.py:277(_raw_path)
#         1    0.000    0.000    0.000    0.000 trainer.py:1334(is_global_zero)
#         1    0.000    0.000    0.000    0.000 _local.py:406(is_absolute)
#         1    0.000    0.000    0.000    0.000 enum.py:199(__get__)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 trainer.py:1271(lightning_module)
#         1    0.000    0.000    0.000    0.000 model_checkpoint.py:837(__resolve_ckpt_dir)
#         1    0.000    0.000    0.000    0.000 warnings.py:425(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x150d170}
#         2    0.000    0.000    0.000    0.000 {built-in method _stat.S_ISDIR}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         3    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 iostream.py:139(_event_pipe)
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of 'posix.ScandirIterator' objects}
#         1    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         1    0.000    0.000    0.000    0.000 {built-in method _stat.S_ISLNK}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'is_done' of '_thread._ThreadHandle' objects}
#         1    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 enum.py:1337(value)
#         3    0.000    0.000    0.000    0.000 trainer.py:1218(strategy)
#         1    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#         1    0.000    0.000    0.000    0.000 <string>:2(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         1    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 typing.py:2371(cast)
#         1    0.000    0.000    0.000    0.000 spec.py:219(_get_kwargs_from_urls)
#         1    0.000    0.000    0.000    0.000 spec.py:67(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _local.py:298(root)
#         1    0.000    0.000    0.000    0.000 _local.py:307(_tail)
#         1    0.000    0.000    0.000    0.000 displaypub.py:172(is_publishing)
#         1    0.000    0.000    0.000    0.000 threading.py:605(is_set)
#         1    0.000    0.000    0.000    0.000 single_device.py:81(is_global_zero)
#         1    0.000    0.000    0.000    0.000 displayhook.py:118(is_active)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         1    0.000    0.000    0.000    0.000 single_device.py:90(broadcast)
#
#
#
# Profile stats for: [LightningModule]LitAutoEncoder.setup
#          7 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:56(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:81(stop)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 hooks.py:421(setup)
#
#
#
# Profile stats for: [LightningModule]LitAutoEncoder.configure_optimizers
#          375 function calls (325 primitive calls) in 0.001 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 3884627641.py:62(configure_optimizers)
#         1    0.000    0.000    0.000    0.000 adam.py:35(__init__)
#         1    0.000    0.000    0.000    0.000 optimizer.py:373(__init__)
#        13    0.000    0.000    0.000    0.000 module.py:2656(parameters)
#        13    0.000    0.000    0.000    0.000 module.py:2681(named_parameters)
#        13    0.000    0.000    0.000    0.000 module.py:2636(_named_members)
#         1    0.000    0.000    0.000    0.000 _compile.py:41(inner)
#         1    0.000    0.000    0.000    0.000 eval_frame.py:1039(_fn)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:56(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:81(stop)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 optimizer.py:1069(add_param_group)
#     66/16    0.000    0.000    0.000    0.000 module.py:2823(named_modules)
#        48    0.000    0.000    0.000    0.000 _tensor.py:1183(__hash__)
#        27    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._log_api_usage_once}
#        15    0.000    0.000    0.000    0.000 module.py:2706(<lambda>)
#        34    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        48    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#        31    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 optimizer.py:548(_patch_step_function)
#         2    0.000    0.000    0.000    0.000 eval_frame.py:148(_maybe_set_eval_frame)
#        11    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#        13    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 eval_frame.py:201(_callback_from_stance)
#        13    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         4    0.000    0.000    0.000    0.000 {built-in method torch._C._dynamo.eval_frame.set_eval_frame}
#         1    0.000    0.000    0.000    0.000 {method 'isdisjoint' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 _utils_internal.py:179(justknobs_check)
#         1    0.000    0.000    0.000    0.000 typing.py:2371(cast)
#
#
#
# Profile stats for: [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_fit_start
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:56(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:81(stop)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1271(lightning_module)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1218(strategy)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         1    0.000    0.000    0.000    0.000 callback.py:64(on_fit_start)
#
#
#
# Profile stats for: [Callback]ModelSummary.on_fit_start
#          315 function calls (263 primitive calls) in 0.001 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.001    0.001 model_summary.py:59(on_fit_start)
#         1    0.000    0.000    0.001    0.001 model_summary.py:85(_summary)
#         1    0.000    0.000    0.001    0.001 model_summary.py:552(summarize)
#         1    0.000    0.000    0.001    0.001 model_summary.py:214(__init__)
#         1    0.000    0.000    0.001    0.001 model_summary.py:325(summarize)
#        15    0.000    0.000    0.000    0.000 model_summary.py:326(<genexpr>)
#        14    0.000    0.000    0.000    0.000 model_summary.py:75(__init__)
#        14    0.000    0.000    0.000    0.000 model_summary.py:85(_register_hook)
#         1    0.000    0.000    0.000    0.000 model_summary.py:339(_forward_example_input)
#         1    0.000    0.000    0.000    0.000 module.py:355(_on_before_batch_transfer)
#         1    0.000    0.000    0.000    0.000 module.py:340(_call_batch_hook)
#        14    0.000    0.000    0.000    0.000 module.py:1678(register_forward_hook)
#         1    0.000    0.000    0.000    0.000 call.py:155(_call_lightning_module_hook)
#         1    0.000    0.000    0.000    0.000 contextlib.py:136(__enter__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:56(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:74(start)
#         9    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        14    0.000    0.000    0.000    0.000 hooks.py:24(__init__)
#         1    0.000    0.000    0.000    0.000 flop_counter.py:636(__init__)
#         1    0.000    0.000    0.000    0.000 model_summary.py:250(named_modules)
#     66/16    0.000    0.000    0.000    0.000 module.py:2823(named_modules)
#     50/48    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 module.py:1968(__setattr__)
#         1    0.000    0.000    0.000    0.000 module_tracker.py:64(__init__)
#        42    0.000    0.000    0.000    0.000 hooks.py:33(<genexpr>)
#         1    0.000    0.000    0.000    0.000 parameter.py:21(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:303(helper)
#        15    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 weakref.py:367(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen abc>:117(__instancecheck__)
#        16    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 trainer.py:1271(lightning_module)
#         1    0.000    0.000    0.000    0.000 __init__.py:1498(debug)
#         1    0.000    0.000    0.000    0.000 parameter.py:233(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:37(__init__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:108(__init__)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         3    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 data_connector.py:359(get_instance)
#         1    0.000    0.000    0.000    0.000 __init__.py:1765(isEnabledFor)
#         3    0.000    0.000    0.000    0.000 trainer.py:1218(strategy)
#         2    0.000    0.000    0.000    0.000 {function _ParameterMeta.__instancecheck__ at 0x7fa456d84540}
#         2    0.000    0.000    0.000    0.000 module.py:247(example_input_array)
#         2    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#
#
#
# Profile stats for: [LightningModule]LitAutoEncoder.on_before_batch_transfer
#          32851 function calls in 0.362 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      4693    0.002    0.000    0.361    0.000 contextlib.py:145(__exit__)
#      4693    0.002    0.000    0.359    0.000 {built-in method builtins.next}
#      4693    0.004    0.000    0.357    0.000 profiler.py:56(profile)
#      4693    0.004    0.000    0.354    0.000 advanced.py:81(stop)
#      4693    0.348    0.000    0.348    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#      4693    0.002    0.000    0.002    0.000 {method 'get' of 'dict' objects}
#      4693    0.001    0.000    0.001    0.000 hooks.py:614(on_before_batch_transfer)
#
#
#
# Profile stats for: [LightningModule]LitAutoEncoder.transfer_batch_to_device
#          1307914 function calls (1100834 primitive calls) in 3.130 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      4693    0.007    0.000    0.426    0.000 contextlib.py:145(__exit__)
#      4693    0.004    0.000    0.419    0.000 {built-in method builtins.next}
#      4693    0.006    0.000    0.415    0.000 profiler.py:56(profile)
#      4693    0.011    0.000    0.410    0.000 advanced.py:81(stop)
#      4693    0.397    0.000    0.397    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#      8514    0.026    0.000    0.370    0.000 zmqstream.py:653(_rebuild_io_state)
#      8514    0.022    0.000    0.252    0.000 zmqstream.py:676(_update_handler)
#      3311    0.046    0.000    0.231    0.000 reduction.py:48(dumps)
#     15196    0.049    0.000    0.186    0.000 attrsettr.py:43(__getattr__)
#     23710    0.059    0.000    0.172    0.000 enum.py:1607(__and__)
# 251376/234348    0.082    0.000    0.142    0.000 {built-in method builtins.isinstance}
#      3311    0.076    0.000    0.124    0.000 reduction.py:38(__init__)
#     97674    0.069    0.000    0.109    0.000 enum.py:1589(_get_value)
#     15196    0.073    0.000    0.093    0.000 attrsettr.py:66(_get_attr_opt)
#     54447    0.043    0.000    0.071    0.000 enum.py:695(__call__)
#      6682    0.018    0.000    0.066    0.000 asyncio.py:231(add_callback)
#      8848    0.021    0.000    0.059    0.000 enum.py:1596(__or__)
#      3311    0.055    0.000    0.055    0.000 {method 'dump' of '_pickle.Pickler' objects}
#      8514    0.009    0.000    0.047    0.000 typing.py:1374(__instancecheck__)
#      6682    0.010    0.000    0.046    0.000 base_events.py:823(call_soon)
#      8514    0.012    0.000    0.038    0.000 typing.py:1665(__subclasscheck__)
#      3311    0.038    0.000    0.038    0.000 {method 'update' of 'dict' objects}
#     20079    0.021    0.000    0.034    0.000 typing.py:426(inner)
#      6682    0.015    0.000    0.034    0.000 base_events.py:852(_call_soon)
#      8514    0.007    0.000    0.033    0.000 zmqstream.py:532(sending)
#       727    0.008    0.000    0.032    0.000 connection.py:875(_create_response)
#  6726/341    0.006    0.000    0.030    0.000 zmqstream.py:684(<lambda>)
#  7433/414    0.008    0.000    0.030    0.000 {method 'run' of '_contextvars.Context' objects}
#  7460/414    0.009    0.000    0.029    0.000 ioloop.py:750(_run_callback)
#     15196    0.019    0.000    0.027    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#     54447    0.027    0.000    0.027    0.000 enum.py:1156(__new__)
#      8514    0.015    0.000    0.026    0.000 queue.py:112(empty)
#      4692    0.006    0.000    0.024    0.000 {built-in method builtins.all}
#      8514    0.010    0.000    0.021    0.000 {built-in method builtins.issubclass}
#  7430/284    0.011    0.000    0.021    0.000 events.py:87(_run)
#       581    0.021    0.000    0.021    0.000 {built-in method _new_shared_fd_cpu}
#     60897    0.020    0.000    0.020    0.000 {built-in method builtins.len}
#      1205    0.004    0.000    0.019    0.000 hmac.py:167(new)
#     14076    0.006    0.000    0.018    0.000 apply_func.py:67(<genexpr>)
#     14401    0.007    0.000    0.018    0.000 <frozen abc>:117(__instancecheck__)
#      6682    0.012    0.000    0.017    0.000 events.py:36(__init__)
#       478    0.004    0.000    0.016    0.000 connection.py:903(_verify_challenge)
#      1205    0.005    0.000    0.015    0.000 hmac.py:38(__init__)
#  6693/950    0.064    0.000    0.015    0.000 socket.py:771(recv_multipart)
#      2834    0.007    0.000    0.014    0.000 threading.py:315(_acquire_restore)
#     13386    0.009    0.000    0.013    0.000 typing.py:1443(__hash__)
#     12234    0.013    0.000    0.013    0.000 {method 'popleft' of 'collections.deque' objects}
#       593    0.007    0.000    0.012    0.000 reductions.py:577(rebuild_typed_storage)
#      8622    0.008    0.000    0.012    0.000 <frozen abc>:121(__subclasscheck__)
#  6813/144    0.031    0.000    0.012    0.000 zmqstream.py:573(_handle_events)
#     16132    0.011    0.000    0.011    0.000 {built-in method builtins.getattr}
#      5087    0.011    0.000    0.011    0.000 {built-in method _struct.pack}
#      8970    0.007    0.000    0.010    0.000 base_events.py:772(time)
#     14401    0.010    0.000    0.010    0.000 {built-in method _abc._abc_instancecheck}
#      3311    0.010    0.000    0.010    0.000 {method 'copy' of 'dict' objects}
#      1205    0.006    0.000    0.010    0.000 connection.py:849(_get_digest_name_and_payload)
#      1205    0.004    0.000    0.010    0.000 hmac.py:66(_init_hmac)
#       581    0.003    0.000    0.009    0.000 reductions.py:81(__setitem__)
#       742    0.003    0.000    0.008    0.000 iostream.py:611(_flush)
#      8514    0.006    0.000    0.008    0.000 queue.py:266(_qsize)
#      8195    0.008    0.000    0.008    0.000 connection.py:135(_check_closed)
#      1205    0.003    0.000    0.007    0.000 hmac.py:151(digest)
#       581    0.002    0.000    0.006    0.000 reductions.py:533(storage_from_cache)
#     15196    0.006    0.000    0.006    0.000 {method 'upper' of 'str' objects}
#      3311    0.006    0.000    0.006    0.000 {method 'getbuffer' of '_io.BytesIO' objects}
#      1205    0.006    0.000    0.006    0.000 {built-in method _hashlib.hmac_new}
#     15207    0.006    0.000    0.006    0.000 {built-in method builtins.hasattr}
#      2032    0.003    0.000    0.006    0.000 threading.py:318(_is_owned)
#  1162/522    0.002    0.000    0.006    0.000 reductions.py:525(fd_id)
#       655    0.003    0.000    0.006    0.000 {built-in method _heapq.heappop}
#         8    0.002    0.000    0.005    0.001 reductions.py:87(free_dead_references)
#      9369    0.005    0.000    0.005    0.000 {method 'append' of 'collections.deque' objects}
#      1872    0.004    0.000    0.005    0.000 connection.py:96(address_type)
#       742    0.002    0.000    0.005    0.000 iostream.py:705(_flush_buffers)
#      8622    0.005    0.000    0.005    0.000 {built-in method _abc._abc_subclasscheck}
#      2888    0.005    0.000    0.005    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#       581    0.003    0.000    0.004    0.000 reductions.py:77(get)
#      4686    0.004    0.000    0.004    0.000 {method 'write' of '_io.BytesIO' objects}
#     13386    0.004    0.000    0.004    0.000 {built-in method builtins.hash}
#     15196    0.004    0.000    0.004    0.000 zmqstream.py:528(receiving)
#       790    0.003    0.000    0.004    0.000 socket.py:507(detach)
#      4809    0.004    0.000    0.004    0.000 {method 'release' of '_thread.lock' objects}
#      5857    0.004    0.000    0.004    0.000 {method 'get' of 'dict' objects}
#       936    0.002    0.000    0.004    0.000 <frozen importlib._bootstrap>:645(parent)
#      9733    0.004    0.000    0.004    0.000 {method '__exit__' of '_thread.lock' objects}
#       475    0.001    0.000    0.004    0.000 selectors.py:206(__exit__)
#      9132    0.003    0.000    0.003    0.000 {built-in method time.monotonic}
#      1205    0.003    0.000    0.003    0.000 {method 'digest' of '_hashlib.HMAC' objects}
#      2341    0.003    0.000    0.003    0.000 {built-in method _struct.unpack}
#   2377/31    0.025    0.000    0.003    0.000 connection.py:429(_recv_bytes)
#      1978    0.002    0.000    0.003    0.000 threading.py:312(_release_save)
#      6910    0.003    0.000    0.003    0.000 selector_events.py:740(_process_events)
#      3366    0.002    0.000    0.003    0.000 events.py:129(__lt__)
#       593    0.002    0.000    0.003    0.000 storage.py:693(__new__)
#      6682    0.003    0.000    0.003    0.000 {built-in method _contextvars.copy_context}
#    575/35    0.007    0.000    0.003    0.000 connection.py:174(close)
#      2968    0.003    0.000    0.003    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
#    1044/9    0.013    0.000    0.003    0.000 reductions.py:540(rebuild_storage_fd)
#   2335/25    0.019    0.000    0.003    0.000 connection.py:208(recv_bytes)
#       581    0.002    0.000    0.003    0.000 reductions.py:33(__init__)
#       742    0.002    0.000    0.003    0.000 iostream.py:713(_rotate_buffers)
#      4686    0.003    0.000    0.003    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#       593    0.002    0.000    0.003    0.000 storage.py:785(__init__)
#    478/46    0.003    0.000    0.003    0.000 connection.py:202(send)
#       475    0.002    0.000    0.002    0.000 selectors.py:272(close)
#      6682    0.002    0.000    0.002    0.000 {built-in method _asyncio.get_running_loop}
#      1978    0.002    0.000    0.002    0.000 {built-in method _thread.allocate_lock}
#      6682    0.002    0.000    0.002    0.000 base_events.py:554(_check_closed)
#     390/8    0.016    0.000    0.002    0.000 {built-in method _pickle.loads}
#    4382/8    0.053    0.000    0.002    0.000 hooks.py:565(transfer_batch_to_device)
#      5087    0.002    0.000    0.002    0.000 connection.py:143(_check_writable)
#      6682    0.002    0.000    0.002    0.000 base_events.py:2068(get_debug)
#       790    0.002    0.000    0.002    0.000 connection.py:118(__init__)
#      1024    0.001    0.000    0.002    0.000 reductions.py:49(__del__)
#      1032    0.001    0.000    0.002    0.000 reductions.py:46(expired)
#      2102    0.002    0.000    0.002    0.000 {built-in method math.ceil}
#      97/4    0.002    0.000    0.002    0.000 queues.py:96(get)
#      6693    0.001    0.000    0.001    0.000 typing.py:2371(cast)
#    553/14    0.009    0.000    0.001    0.000 reduction.py:186(recv_handle)
#       936    0.001    0.000    0.001    0.000 {method 'rpartition' of 'str' objects}
#        54    0.001    0.000    0.001    0.000 queue.py:137(put)
#       936    0.001    0.000    0.001    0.000 connection.py:84(_validate_family)
#        54    0.000    0.000    0.001    0.000 selectors.py:340(register)
#     447/6    0.008    0.000    0.001    0.000 connection.py:928(deliver_challenge)
#      1205    0.001    0.000    0.001    0.000 {method 'find' of 'bytes' objects}
#   6867/57    0.018    0.000    0.001    0.000 zmqstream.py:614(_handle_recv)
#      1024    0.000    0.000    0.001    0.000 storage.py:1265(_free_weak_ref)
#      1932    0.001    0.000    0.001    0.000 {method 'startswith' of 'bytes' objects}
#      1298    0.001    0.000    0.001    0.000 {method 'encode' of 'str' objects}
#    4377/6    0.039    0.000    0.001    0.000 apply_func.py:78(move_data_to_device)
#        54    0.000    0.000    0.001    0.000 selectors.py:238(register)
#      1205    0.001    0.000    0.001    0.000 {method 'decode' of 'bytes' objects}
#     536/9    0.005    0.000    0.001    0.000 connection.py:262(__exit__)
#       484    0.001    0.000    0.001    0.000 {built-in method posix.getpid}
#       936    0.001    0.000    0.001    0.000 process.py:213(authkey)
#      2571    0.001    0.000    0.001    0.000 connection.py:139(_check_readable)
#      1872    0.001    0.000    0.001    0.000 {method 'startswith' of 'str' objects}
#      1032    0.000    0.000    0.001    0.000 storage.py:1431(_expired)
#       549    0.001    0.000    0.001    0.000 {method 'frombytes' of 'array.array' objects}
#       790    0.001    0.000    0.001    0.000 {function socket.detach at 0x7fa5276cec00}
#   1155/90    0.011    0.000    0.001    0.000 {built-in method posix.fstat}
#       537    0.001    0.000    0.001    0.000 connection.py:169(fileno)
#       647    0.001    0.000    0.001    0.000 {built-in method __new__ of type object at 0x150d170}
#      1024    0.001    0.000    0.001    0.000 {built-in method _free_weak_ref}
#     567/9    0.011    0.000    0.001    0.000 reductions.py:110(rebuild_tensor)
#       475    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#        54    0.000    0.000    0.001    0.000 selectors.py:336(__init__)
#       936    0.001    0.000    0.001    0.000 process.py:37(current_process)
#       475    0.001    0.000    0.001    0.000 {method 'clear' of 'dict' objects}
#       581    0.001    0.000    0.001    0.000 {method '_weak_ref' of 'torch._C.StorageBase' objects}
#    579/23    0.006    0.000    0.001    0.000 connection.py:376(_close)
#       488    0.001    0.000    0.001    0.000 {built-in method _socket.CMSG_SPACE}
#   9392/37    0.164    0.000    0.001    0.000 {method 'to' of 'torch._C.TensorBase' objects}
#       108    0.000    0.000    0.001    0.000 copy.py:62(copy)
#      1393    0.000    0.000    0.000    0.000 socket.py:237(__enter__)
#       478    0.000    0.000    0.000    0.000 {built-in method _hashlib.compare_digest}
#      1205    0.000    0.000    0.000    0.000 hmac.py:139(_current)
#         6    0.000    0.000    0.000    0.000 _monitor.py:47(get_instances)
#        54    0.000    0.000    0.000    0.000 selectors.py:219(_fileobj_lookup)
#      98/1    0.002    0.000    0.000    0.000 pin_memory.py:26(do_one_step)
#       742    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#       750    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#   6893/57    0.011    0.000    0.000    0.000 zmqstream.py:546(_run_callback)
#      1032    0.000    0.000    0.000    0.000 {built-in method _expired}
#     354/1    0.004    0.000    0.000    0.000 connection.py:510(Client)
#       580    0.000    0.000    0.000    0.000 connection.py:131(__del__)
#    7349/4    0.068    0.000    0.000    0.000 base_events.py:1970(_run_once)
#        54    0.000    0.000    0.000    0.000 selectors.py:21(_fileobj_to_fd)
#         6    0.000    0.000    0.000    0.000 _weakrefset.py:95(copy)
#         6    0.000    0.000    0.000    0.000 _weakrefset.py:37(__init__)
#     600/2    0.010    0.000    0.000    0.000 connection.py:949(answer_challenge)
#        54    0.000    0.000    0.000    0.000 threading.py:398(notify)
#        54    0.000    0.000    0.000    0.000 selectors.py:213(__init__)
#         2    0.000    0.000    0.000    0.000 threading.py:641(wait)
#         6    0.000    0.000    0.000    0.000 _weakrefset.py:120(update)
#        57    0.000    0.000    0.000    0.000 threading.py:303(__enter__)
#  11077/38    0.079    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#    9618/7    0.075    0.000    0.000    0.000 apply_func.py:98(batch_to)
#        28    0.000    0.000    0.000    0.000 _weakrefset.py:63(__iter__)
#     558/6    0.012    0.000    0.000    0.000 reduction.py:153(recvfds)
#    5098/2    0.067    0.000    0.000    0.000 apply_func.py:25(apply_to_collection)
#    3726/7    0.037    0.000    0.000    0.000 connection.py:182(send_bytes)
#    4350/9    0.034    0.000    0.000    0.000 connection.py:406(_send_bytes)
#        54    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#    4686/8    0.033    0.000    0.000    0.000 connection.py:390(_recv)
#       483    0.000    0.000    0.000    0.000 connection.py:259(__enter__)
#    488/10    0.002    0.000    0.000    0.000 socket.py:542(fromfd)
#        54    0.000    0.000    0.000    0.000 queue.py:270(_put)
#    4208/9    0.026    0.000    0.000    0.000 connection.py:381(_send)
#        57    0.000    0.000    0.000    0.000 threading.py:306(__exit__)
#    2843/3    0.068    0.000    0.000    0.000 threading.py:327(wait)
#       223    0.000    0.000    0.000    0.000 threading.py:605(is_set)
#       108    0.000    0.000    0.000    0.000 {method 'copy' of 'list' objects}
#        12    0.000    0.000    0.000    0.000 _weakrefset.py:27(__exit__)
#        57    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#     428/3    0.009    0.000    0.000    0.000 {method 'recvmsg' of '_socket.socket' objects}
#     353/1    0.004    0.000    0.000    0.000 connection.py:253(poll)
#       108    0.000    0.000    0.000    0.000 <frozen _collections_abc>:345(__subclasshook__)
#     487/4    0.009    0.000    0.000    0.000 {method 'set_' of 'torch._C.TensorBase' objects}
#        54    0.000    0.000    0.000    0.000 {method 'register' of 'select.poll' objects}
#     418/1    0.005    0.000    0.000    0.000 connection.py:439(_poll)
#        54    0.000    0.000    0.000    0.000 {built-in method select.poll}
#   1337/21    0.002    0.000    0.000    0.000 socket.py:240(__exit__)
#    4344/2    0.046    0.000    0.000    0.000 {built-in method posix.read}
#    3940/9    0.053    0.000    0.000    0.000 {built-in method posix.write}
#     443/1    0.008    0.000    0.000    0.000 connection.py:1134(wait)
#     551/2    0.007    0.000    0.000    0.000 _utils.py:185(_rebuild_tensor)
#        12    0.000    0.000    0.000    0.000 _weakrefset.py:53(_commit_removals)
#    2299/6    0.045    0.000    0.000    0.000 socket.py:623(send)
#     547/5    0.001    0.000    0.000    0.000 socket.py:501(close)
#         8    0.000    0.000    0.000    0.000 _weakrefset.py:85(add)
#         3    0.000    0.000    0.000    0.000 std.py:110(__enter__)
#        20    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#     547/5    0.001    0.000    0.000    0.000 socket.py:497(_real_close)
#     533/3    0.007    0.000    0.000    0.000 {built-in method posix.urandom}
#         3    0.000    0.000    0.000    0.000 std.py:102(acquire)
#     446/1    0.014    0.000    0.000    0.000 selectors.py:385(select)
#    1758/1    0.013    0.000    0.000    0.000 iostream.py:277(<lambda>)
#         3    0.000    0.000    0.000    0.000 std.py:113(__exit__)
#     637/2    0.011    0.000    0.000    0.000 {method 'connect' of '_socket.socket' objects}
#     521/2    0.012    0.000    0.000    0.000 {built-in method torch.empty}
#    1780/1    0.016    0.000    0.000    0.000 iostream.py:279(_really_send)
#        12    0.000    0.000    0.000    0.000 _weakrefset.py:21(__enter__)
#         3    0.000    0.000    0.000    0.000 std.py:106(release)
#     108/1    0.002    0.000    0.000    0.000 {method 'poll' of 'select.poll' objects}
#     546/5    0.003    0.000    0.000    0.000 {function socket.close at 0x7fa5276ceb60}
#     873/4    0.006    0.000    0.000    0.000 {method 'setblocking' of '_socket.socket' objects}
#         4    0.000    0.000    0.000    0.000 iostream.py:217(_check_mp_mode)
#        54    0.000    0.000    0.000    0.000 selectors.py:63(__init__)
#         3    0.000    0.000    0.000    0.000 std.py:760(get_lock)
#    1790/1    0.015    0.000    0.000    0.000 socket.py:700(send_multipart)
#         8    0.000    0.000    0.000    0.000 std.py:1157(__hash__)
#    6959/4    0.018    0.000    0.000    0.000 selectors.py:435(select)
#     482/4    0.003    0.000    0.000    0.000 {built-in method _socket.dup}
#    1390/3    0.019    0.000    0.000    0.000 socket.py:221(__init__)
#         4    0.000    0.000    0.000    0.000 iostream.py:214(_is_master_process)
#        12    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        54    0.000    0.000    0.000    0.000 selectors.py:203(__enter__)
#    6750/4    0.034    0.000    0.000    0.000 {method 'poll' of 'select.epoll' objects}
#        12    0.000    0.000    0.000    0.000 _weakrefset.py:17(__init__)
#        12    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         3    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         3    0.000    0.000    0.000    0.000 {built-in method time.time}
#    8475/4    0.019    0.000    0.000    0.000 iostream.py:158(_handle_event)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         3    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#    1036/1    0.011    0.000    0.000    0.000 {built-in method posix.close}
#         4    0.000    0.000    0.000    0.000 iostream.py:256(closed)
#      93/0    0.004    0.000    0.000          {method 'pin_memory' of 'torch._C.TensorBase' objects}
#     249/0    0.006    0.000    0.000          pin_memory.py:55(pin_memory)
#     790/0    0.017    0.000    0.000          connection.py:640(SocketClient)
#     349/0    0.005    0.000    0.000          resource_sharer.py:81(get_connection)
#     730/0    0.009    0.000    0.000          resource_sharer.py:55(detach)
#
#
#
# Profile stats for: [LightningModule]LitAutoEncoder.on_after_batch_transfer
#          32851 function calls in 0.346 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      4693    0.002    0.000    0.346    0.000 contextlib.py:145(__exit__)
#      4693    0.002    0.000    0.344    0.000 {built-in method builtins.next}
#      4693    0.003    0.000    0.342    0.000 profiler.py:56(profile)
#      4693    0.004    0.000    0.338    0.000 advanced.py:81(stop)
#      4693    0.333    0.000    0.333    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#      4693    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#      4693    0.001    0.000    0.001    0.000 hooks.py:642(on_after_batch_transfer)
#
#
#
# Profile stats for: [Callback]TQDMProgressBar.on_fit_start
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:56(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:81(stop)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1271(lightning_module)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1218(strategy)
#         1    0.000    0.000    0.000    0.000 callback.py:64(on_fit_start)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#
#
#
# Profile stats for: [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_start
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:56(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:81(stop)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1271(lightning_module)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1218(strategy)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         1    0.000    0.000    0.000    0.000 callback.py:64(on_fit_start)
#
#
#
# Profile stats for: [LightningModule]LitAutoEncoder.on_fit_start
#          7 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
# ...
#         3    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 base_events.py:2068(get_debug)
#         6    0.000    0.000    0.000    0.000 {method 'is_done' of '_thread._ThreadHandle' objects}
#         1    0.000    0.000    0.000    0.000 iostream.py:365(fileno)
#         1    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 base_events.py:554(_check_closed)
#         1    0.000    0.000    0.000    0.000 threading.py:315(_acquire_restore)
#         3    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 utils.py:139(__getattr__)
#         1    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         6    0.000    0.000    0.000    0.000 threading.py:605(is_set)
#         2    0.000    0.000    0.000    0.000 selector_events.py:740(_process_events)
#         1    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x150d170}
#         2    0.000    0.000    0.000    0.000 threading.py:1112(ident)
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#         1    0.000    0.000    0.000    0.000 traitlets.py:2558(_validate_bounds)
#         1    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:17(__init__)
#         2    0.000    0.000    0.000    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1271(lightning_module)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.StringIO' objects}
#         3    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#         3    0.000    0.000    0.000    0.000 displaypub.py:172(is_publishing)
#         1    0.000    0.000    0.000    0.000 iostream.py:256(closed)
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 hmac.py:139(_current)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         2    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 utils.py:112(__format__)
#         3    0.000    0.000    0.000    0.000 displayhook.py:118(is_active)
#         1    0.000    0.000    0.000    0.000 std.py:167(colour)
#         1    0.000    0.000    0.000    0.000 tqdm_progress.py:122(train_progress_bar)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000    0.000    0.000 utils.py:108(__init__)
#         1    0.000    0.000    0.000    0.000 <string>:2(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         1    0.000    0.000    0.000    0.000 std.py:163(colour)
#         1    0.000    0.000    0.000    0.000 std.py:1301(<lambda>)
#         1    0.000    0.000    0.000    0.000 trainer.py:1218(strategy)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#
#
#
# Profile stats for: [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_end
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:56(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:81(stop)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 model_checkpoint.py:535(on_train_end)
#         1    0.000    0.000    0.000    0.000 trainer.py:1271(lightning_module)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1218(strategy)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#
#
#
# Profile stats for: [LightningModule]LitAutoEncoder.on_train_end
#          7 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:56(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:81(stop)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 hooks.py:47(on_train_end)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#
#
#
# Profile stats for: [Strategy]SingleDeviceStrategy.on_train_end
#          7 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:56(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:81(stop)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 strategy.py:562(on_train_end)
#
#
#
# Profile stats for: [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_fit_end
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:56(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:81(stop)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1271(lightning_module)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1218(strategy)
#         1    0.000    0.000    0.000    0.000 callback.py:67(on_fit_end)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#
#
#
# Profile stats for: [Callback]ModelSummary.on_fit_end
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:56(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:81(stop)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1271(lightning_module)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         1    0.000    0.000    0.000    0.000 trainer.py:1218(strategy)
#         1    0.000    0.000    0.000    0.000 callback.py:67(on_fit_end)
#
#
#
# Profile stats for: [Callback]TQDMProgressBar.on_fit_end
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:56(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:81(stop)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1271(lightning_module)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1218(strategy)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         1    0.000    0.000    0.000    0.000 callback.py:67(on_fit_end)
#
#
#
# Profile stats for: [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_end
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:56(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:81(stop)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1271(lightning_module)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1218(strategy)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         1    0.000    0.000    0.000    0.000 callback.py:67(on_fit_end)
#
#
#
# Profile stats for: [LightningModule]LitAutoEncoder.on_fit_end
#          7 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:56(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:81(stop)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 hooks.py:37(on_fit_end)
#
#
#
# Profile stats for: [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.teardown
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:56(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:81(stop)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1271(lightning_module)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1218(strategy)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         1    0.000    0.000    0.000    0.000 callback.py:61(teardown)
#
#
#
# Profile stats for: [Callback]ModelSummary.teardown
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:56(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:81(stop)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1271(lightning_module)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         1    0.000    0.000    0.000    0.000 trainer.py:1218(strategy)
#         1    0.000    0.000    0.000    0.000 callback.py:61(teardown)
#
#
#
# Profile stats for: [Callback]TQDMProgressBar.teardown
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:56(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:81(stop)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1271(lightning_module)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 callback.py:61(teardown)
#         1    0.000    0.000    0.000    0.000 trainer.py:1218(strategy)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#
#
#
# Profile stats for: [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.teardown
#          10 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:56(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:81(stop)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1271(lightning_module)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 trainer.py:1218(strategy)
#         1    0.000    0.000    0.000    0.000 strategy.py:361(lightning_module)
#         1    0.000    0.000    0.000    0.000 callback.py:61(teardown)
#
#
#
# Profile stats for: [LightningModule]LitAutoEncoder.teardown
#          7 function calls in 0.000 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 contextlib.py:145(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 profiler.py:56(profile)
#         1    0.000    0.000    0.000    0.000 advanced.py:81(stop)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 hooks.py:448(teardown)

# %% [markdown]
# If the profiler report becomes too long, you can stream the report to a file:

# %%
from lightning.pytorch.profilers import AdvancedProfiler

profiler = AdvancedProfiler(dirpath=".", filename="perf_logs")
trainer = Trainer(
    profiler=profiler,
    logger=logger,
    callbacks=[checkpoint_callback, early_stop_callback, model_summary_callback],
    accelerator="gpu",
    devices=1,
    max_epochs=10
)
# Out:
# /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib ...
# Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores

# %%
trainer.fit(model, train_loader, valid_loader)
# Out:
# /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib ...
# /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:881: Checkpoint directory /storage3/DSIP/rriva/tutorials/pl_tutorial/basic/logs/find_bottlenecks/version_4/checkpoints exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
#    | Name         | Type       | Params | Mode  | FLOPs  | In sizes     | Out sizes
# --------------------------------------------------------------------------------------------
# 0  | encoder      | Encoder    | 558 K  | train | 35.7 M | [32, 1, 784] | [32, 1, 100]
# 1  | encoder.ff   | Sequential | 558 K  | train | 35.7 M | [32, 1, 784] | [32, 1, 100]
# 2  | encoder.ff.0 | Linear     | 401 K  | train | 25.7 M | [32, 1, 784] | [32, 1, 512]
# 3  | encoder.ff.1 | ReLU       | 0      | train | 0      | [32, 1, 512] | [32, 1, 512]
# 4  | encoder.ff.2 | Linear     | 131 K  | train | 8.4 M  | [32, 1, 512] | [32, 1, 256]
# 5  | encoder.ff.3 | ReLU       | 0      | train | 0      | [32, 1, 256] | [32, 1, 256]
# 6  | encoder.ff.4 | Linear     | 25.7 K | train | 1.6 M  | [32, 1, 256] | [32, 1, 100]
# 7  | decoder      | Decoder    | 247 K  | train | 15.8 M | [32, 1, 100] | [32, 1, 784]
# 8  | decoder.ff   | Sequential | 247 K  | train | 15.8 M | [32, 1, 100] | [32, 1, 784]
# 9  | decoder.ff.0 | Linear     | 12.9 K | train | 819 K  | [32, 1, 100] | [32, 1, 128]
# 10 | decoder.ff.1 | ReLU       | 0      | train | 0      | [32, 1, 128] | [32, 1, 128]
# 11 | decoder.ff.2 | Linear     | 33.0 K | train | 2.1 M  | [32, 1, 128] | [32, 1, 256]
# 12 | decoder.ff.3 | ReLU       | 0      | train | 0      | [32, 1, 256] | [32, 1, 256]
# 13 | decoder.ff.4 | Linear     | 201 K  | train | 12.8 M | [32, 1, 256] | [32, 1, 784]
# --------------------------------------------------------------------------------------------
# 806 K     Trainable params
# 0         Non-trainable params
# 806 K     Total params
# 3.226     Total estimated model params size (MB)
# 14        Modules in train mode
# 0         Modules in eval mode
# 51.5 M    Total Flops
# Epoch 9: 100%|██████████| 375/375 [00:08<00:00, 44.37it/s, v_num=4, val_loss=0.0098, train_loss=0.00981]
# `Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100%|██████████| 375/375 [00:08<00:00, 43.48it/s, v_num=4, val_loss=0.0098, train_loss=0.00981]

# %% [markdown]
# ### Measure accelerator usage
# Another helpful technique to detect bottlenecks is to ensure that you’re using the full capacity of your accelerator (GPU/TPU/HPU). This can be measured with the `DeviceStatsMonitor`:

# %%
from lightning.pytorch.callbacks import DeviceStatsMonitor
trainer = Trainer(
    profiler=profiler,
    logger=logger,
    callbacks=[checkpoint_callback, early_stop_callback, model_summary_callback, DeviceStatsMonitor()],
    accelerator="gpu",
    devices=1,
    max_epochs=10
)
# Out:
# Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores

# %%
trainer.fit(model, train_loader, valid_loader)
# Out:
# /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib ...
# /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:881: Checkpoint directory /storage3/DSIP/rriva/tutorials/pl_tutorial/basic/logs/find_bottlenecks/version_4/checkpoints exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#
#    | Name         | Type       | Params | Mode  | FLOPs  | In sizes     | Out sizes
# --------------------------------------------------------------------------------------------
# 0  | encoder      | Encoder    | 558 K  | train | 35.7 M | [32, 1, 784] | [32, 1, 100]
# 1  | encoder.ff   | Sequential | 558 K  | train | 35.7 M | [32, 1, 784] | [32, 1, 100]
# 2  | encoder.ff.0 | Linear     | 401 K  | train | 25.7 M | [32, 1, 784] | [32, 1, 512]
# 3  | encoder.ff.1 | ReLU       | 0      | train | 0      | [32, 1, 512] | [32, 1, 512]
# 4  | encoder.ff.2 | Linear     | 131 K  | train | 8.4 M  | [32, 1, 512] | [32, 1, 256]
# 5  | encoder.ff.3 | ReLU       | 0      | train | 0      | [32, 1, 256] | [32, 1, 256]
# 6  | encoder.ff.4 | Linear     | 25.7 K | train | 1.6 M  | [32, 1, 256] | [32, 1, 100]
# 7  | decoder      | Decoder    | 247 K  | train | 15.8 M | [32, 1, 100] | [32, 1, 784]
# 8  | decoder.ff   | Sequential | 247 K  | train | 15.8 M | [32, 1, 100] | [32, 1, 784]
# 9  | decoder.ff.0 | Linear     | 12.9 K | train | 819 K  | [32, 1, 100] | [32, 1, 128]
# 10 | decoder.ff.1 | ReLU       | 0      | train | 0      | [32, 1, 128] | [32, 1, 128]
# 11 | decoder.ff.2 | Linear     | 33.0 K | train | 2.1 M  | [32, 1, 128] | [32, 1, 256]
# 12 | decoder.ff.3 | ReLU       | 0      | train | 0      | [32, 1, 256] | [32, 1, 256]
# 13 | decoder.ff.4 | Linear     | 201 K  | train | 12.8 M | [32, 1, 256] | [32, 1, 784]
# --------------------------------------------------------------------------------------------
# 806 K     Trainable params
# 0         Non-trainable params
# 806 K     Total params
# 3.226     Total estimated model params size (MB)
# 14        Modules in train mode
# 0         Modules in eval mode
# 51.5 M    Total Flops
# Epoch 9: 100%|██████████| 375/375 [00:09<00:00, 41.28it/s, v_num=4, val_loss=0.00944, train_loss=0.00944]
# `Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100%|██████████| 375/375 [00:09<00:00, 40.62it/s, v_num=4, val_loss=0.00944, train_loss=0.00944]

# %%
import pandas as pd
import os

LOG_DIR = "logs/find_bottlenecks"

# find latest version automatically
versions = sorted(
    [v for v in os.listdir(LOG_DIR) if v.startswith("version_")],
    key=lambda x: int(x.split("_")[1])
)
latest_version = versions[-1]

metrics_path = os.path.join(LOG_DIR, latest_version, "metrics.csv")
df = pd.read_csv(metrics_path)

print(f"Loaded metrics from: {metrics_path}")
print(df.columns)
# Out:
# Loaded metrics from: logs/find_bottlenecks/version_4/metrics.csv
# Index(['step',
#        'test_-DeviceStatsMonitor.on_train_batch_end/active.all.allocated',
#        'test_-DeviceStatsMonitor.on_train_batch_end/active.all.current',
#        'test_-DeviceStatsMonitor.on_train_batch_end/active.all.freed',
#        'test_-DeviceStatsMonitor.on_train_batch_end/active.all.peak',
#        'test_-DeviceStatsMonitor.on_train_batch_end/active.large_pool.allocated',
#        'test_-DeviceStatsMonitor.on_train_batch_end/active.large_pool.current',
#        'test_-DeviceStatsMonitor.on_train_batch_end/active.large_pool.freed',
#        'test_-DeviceStatsMonitor.on_train_batch_end/active.large_pool.peak',
#        'test_-DeviceStatsMonitor.on_train_batch_end/active.small_pool.allocated',
#        ...
#        'test_-DeviceStatsMonitor.on_validation_batch_start/segment.large_pool.peak',
#        'test_-DeviceStatsMonitor.on_validation_batch_start/segment.small_pool.allocated',
#        'test_-DeviceStatsMonitor.on_validation_batch_start/segment.small_pool.current',
#        'test_-DeviceStatsMonitor.on_validation_batch_start/segment.small_pool.freed',
#        'test_-DeviceStatsMonitor.on_validation_batch_start/segment.small_pool.peak',
#        'test_-epoch', 'test_-train/loss_epoch', 'test_-train/loss_step',
#        'test_-train_loss', 'test_-val_loss'],
#       dtype='object', length=494)

# %%
import pandas as pd
import os

LOG_DIR = "logs/find_bottlenecks"
version = sorted(os.listdir(LOG_DIR))[-1]
metrics_path = os.path.join(LOG_DIR, version, "metrics.csv")

df = pd.read_csv(metrics_path)

gpu_cols = [
    c for c in df.columns
    if "gpu" in c.lower()
]

gpu_df = df[gpu_cols].dropna(how="all")

summary = {
    "gpu_utilization_mean (%)": gpu_df["device/gpu_utilization"].mean(),
    "gpu_utilization_max (%)": gpu_df["device/gpu_utilization"].max(),
    "gpu_mem_allocated_mean (MB)": gpu_df["device/gpu_memory_allocated"].mean(),
    "gpu_mem_allocated_max (MB)": gpu_df["device/gpu_memory_allocated"].max(),
}

print("\n=== GPU USAGE SUMMARY ===")
for k, v in summary.items():
    print(f"{k:40s}: {v:.2f}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'device/gpu_utilization'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 18
#      10 gpu_cols = [
#      11     c for c in df.columns
#      12     if "gpu" in c.lower()
#      13 ]
#      15 gpu_df = df[gpu_cols].dropna(how="all")
#      17 summary = {
# ---> 18     "gpu_utilization_mean (%)": gpu_df["device/gpu_utilization"].mean(),
#      19     "gpu_utilization_max (%)": gpu_df["device/gpu_utilization"].max(),
#      20     "gpu_mem_allocated_mean (MB)": gpu_df["device/gpu_memory_allocated"].mean(),
#      21     "gpu_mem_allocated_max (MB)": gpu_df["device/gpu_memory_allocated"].max(),
#      22 }
#      24 print("\n=== GPU USAGE SUMMARY ===")
#      25 for k, v in summary.items():
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'device/gpu_utilization'

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

metrics_path = "logs/find_bottlenecks/version_4/metrics.csv"
df = pd.read_csv(metrics_path)

df = df.dropna(subset=["device/gpu_utilization"])

plt.figure(figsize=(10, 4))
plt.plot(df["device/gpu_utilization"])
plt.xlabel("Training step")
plt.ylabel("GPU utilization (%)")
plt.title("GPU Utilization over Training")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_4110459/2068525225.py in ?()
#       4
#       5 metrics_path = "logs/find_bottlenecks/version_4/metrics.csv"
#       6 df = pd.read_csv(metrics_path)
#       7
# ----> 8 df = df.dropna(subset=["device/gpu_utilization"])
#       9
#      10 plt.figure(figsize=(10, 4))
#      11 plt.plot(df["device/gpu_utilization"])
#
# /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/pandas/core/frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6688             ax = self._get_axis(agg_axis)
#    6689             indices = ax.get_indexer_for(subset)
#    6690             check = indices == -1
#    6691             if check.any():
# -> 6692                 raise KeyError(np.array(subset)[check].tolist())
#    6693             agg_obj = self.take(indices, axis=agg_axis)
#    6694
#    6695         if thresh is not lib.no_default:
#
# KeyError: ['device/gpu_utilization']

# %%
import pandas as pd

df = pd.read_csv("logs/find_bottlenecks/version_4/metrics.csv")

for c in df.columns:
    if "gpu" in c.lower() or "cuda" in c.lower() or 'device' in c.lower():
        print(c)
# Out:
# test_-DeviceStatsMonitor.on_train_batch_end/active.all.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/active.all.current
# test_-DeviceStatsMonitor.on_train_batch_end/active.all.freed
# test_-DeviceStatsMonitor.on_train_batch_end/active.all.peak
# test_-DeviceStatsMonitor.on_train_batch_end/active.large_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/active.large_pool.current
# test_-DeviceStatsMonitor.on_train_batch_end/active.large_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_end/active.large_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_end/active.small_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/active.small_pool.current
# test_-DeviceStatsMonitor.on_train_batch_end/active.small_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_end/active.small_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_end/active_bytes.all.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/active_bytes.all.current
# test_-DeviceStatsMonitor.on_train_batch_end/active_bytes.all.freed
# test_-DeviceStatsMonitor.on_train_batch_end/active_bytes.all.peak
# test_-DeviceStatsMonitor.on_train_batch_end/active_bytes.large_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/active_bytes.large_pool.current
# test_-DeviceStatsMonitor.on_train_batch_end/active_bytes.large_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_end/active_bytes.large_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_end/active_bytes.small_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/active_bytes.small_pool.current
# test_-DeviceStatsMonitor.on_train_batch_end/active_bytes.small_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_end/active_bytes.small_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_end/allocated_bytes.all.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/allocated_bytes.all.current
# test_-DeviceStatsMonitor.on_train_batch_end/allocated_bytes.all.freed
# test_-DeviceStatsMonitor.on_train_batch_end/allocated_bytes.all.peak
# test_-DeviceStatsMonitor.on_train_batch_end/allocated_bytes.large_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/allocated_bytes.large_pool.current
# test_-DeviceStatsMonitor.on_train_batch_end/allocated_bytes.large_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_end/allocated_bytes.large_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_end/allocated_bytes.small_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/allocated_bytes.small_pool.current
# test_-DeviceStatsMonitor.on_train_batch_end/allocated_bytes.small_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_end/allocated_bytes.small_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_end/allocation.all.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/allocation.all.current
# test_-DeviceStatsMonitor.on_train_batch_end/allocation.all.freed
# test_-DeviceStatsMonitor.on_train_batch_end/allocation.all.peak
# test_-DeviceStatsMonitor.on_train_batch_end/allocation.large_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/allocation.large_pool.current
# test_-DeviceStatsMonitor.on_train_batch_end/allocation.large_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_end/allocation.large_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_end/allocation.small_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/allocation.small_pool.current
# test_-DeviceStatsMonitor.on_train_batch_end/allocation.small_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_end/allocation.small_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_end/inactive_split.all.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/inactive_split.all.current
# test_-DeviceStatsMonitor.on_train_batch_end/inactive_split.all.freed
# test_-DeviceStatsMonitor.on_train_batch_end/inactive_split.all.peak
# test_-DeviceStatsMonitor.on_train_batch_end/inactive_split.large_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/inactive_split.large_pool.current
# test_-DeviceStatsMonitor.on_train_batch_end/inactive_split.large_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_end/inactive_split.large_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_end/inactive_split.small_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/inactive_split.small_pool.current
# test_-DeviceStatsMonitor.on_train_batch_end/inactive_split.small_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_end/inactive_split.small_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_end/inactive_split_bytes.all.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/inactive_split_bytes.all.current
# test_-DeviceStatsMonitor.on_train_batch_end/inactive_split_bytes.all.freed
# test_-DeviceStatsMonitor.on_train_batch_end/inactive_split_bytes.all.peak
# test_-DeviceStatsMonitor.on_train_batch_end/inactive_split_bytes.large_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/inactive_split_bytes.large_pool.current
# test_-DeviceStatsMonitor.on_train_batch_end/inactive_split_bytes.large_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_end/inactive_split_bytes.large_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_end/inactive_split_bytes.small_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/inactive_split_bytes.small_pool.current
# test_-DeviceStatsMonitor.on_train_batch_end/inactive_split_bytes.small_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_end/inactive_split_bytes.small_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_end/max_split_size
# test_-DeviceStatsMonitor.on_train_batch_end/num_alloc_retries
# test_-DeviceStatsMonitor.on_train_batch_end/num_device_alloc
# test_-DeviceStatsMonitor.on_train_batch_end/num_device_free
# test_-DeviceStatsMonitor.on_train_batch_end/num_ooms
# test_-DeviceStatsMonitor.on_train_batch_end/num_sync_all_streams
# test_-DeviceStatsMonitor.on_train_batch_end/oversize_allocations.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/oversize_allocations.current
# test_-DeviceStatsMonitor.on_train_batch_end/oversize_allocations.freed
# test_-DeviceStatsMonitor.on_train_batch_end/oversize_allocations.peak
# test_-DeviceStatsMonitor.on_train_batch_end/oversize_segments.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/oversize_segments.current
# test_-DeviceStatsMonitor.on_train_batch_end/oversize_segments.freed
# test_-DeviceStatsMonitor.on_train_batch_end/oversize_segments.peak
# test_-DeviceStatsMonitor.on_train_batch_end/requested_bytes.all.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/requested_bytes.all.current
# test_-DeviceStatsMonitor.on_train_batch_end/requested_bytes.all.freed
# test_-DeviceStatsMonitor.on_train_batch_end/requested_bytes.all.peak
# test_-DeviceStatsMonitor.on_train_batch_end/requested_bytes.large_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/requested_bytes.large_pool.current
# test_-DeviceStatsMonitor.on_train_batch_end/requested_bytes.large_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_end/requested_bytes.large_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_end/requested_bytes.small_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/requested_bytes.small_pool.current
# test_-DeviceStatsMonitor.on_train_batch_end/requested_bytes.small_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_end/requested_bytes.small_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_end/reserved_bytes.all.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/reserved_bytes.all.current
# test_-DeviceStatsMonitor.on_train_batch_end/reserved_bytes.all.freed
# test_-DeviceStatsMonitor.on_train_batch_end/reserved_bytes.all.peak
# test_-DeviceStatsMonitor.on_train_batch_end/reserved_bytes.large_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/reserved_bytes.large_pool.current
# test_-DeviceStatsMonitor.on_train_batch_end/reserved_bytes.large_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_end/reserved_bytes.large_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_end/reserved_bytes.small_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/reserved_bytes.small_pool.current
# test_-DeviceStatsMonitor.on_train_batch_end/reserved_bytes.small_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_end/reserved_bytes.small_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_end/segment.all.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/segment.all.current
# test_-DeviceStatsMonitor.on_train_batch_end/segment.all.freed
# test_-DeviceStatsMonitor.on_train_batch_end/segment.all.peak
# test_-DeviceStatsMonitor.on_train_batch_end/segment.large_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/segment.large_pool.current
# test_-DeviceStatsMonitor.on_train_batch_end/segment.large_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_end/segment.large_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_end/segment.small_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_end/segment.small_pool.current
# test_-DeviceStatsMonitor.on_train_batch_end/segment.small_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_end/segment.small_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_start/active.all.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/active.all.current
# test_-DeviceStatsMonitor.on_train_batch_start/active.all.freed
# test_-DeviceStatsMonitor.on_train_batch_start/active.all.peak
# test_-DeviceStatsMonitor.on_train_batch_start/active.large_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/active.large_pool.current
# test_-DeviceStatsMonitor.on_train_batch_start/active.large_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_start/active.large_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_start/active.small_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/active.small_pool.current
# test_-DeviceStatsMonitor.on_train_batch_start/active.small_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_start/active.small_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_start/active_bytes.all.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/active_bytes.all.current
# test_-DeviceStatsMonitor.on_train_batch_start/active_bytes.all.freed
# test_-DeviceStatsMonitor.on_train_batch_start/active_bytes.all.peak
# test_-DeviceStatsMonitor.on_train_batch_start/active_bytes.large_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/active_bytes.large_pool.current
# test_-DeviceStatsMonitor.on_train_batch_start/active_bytes.large_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_start/active_bytes.large_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_start/active_bytes.small_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/active_bytes.small_pool.current
# test_-DeviceStatsMonitor.on_train_batch_start/active_bytes.small_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_start/active_bytes.small_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_start/allocated_bytes.all.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/allocated_bytes.all.current
# test_-DeviceStatsMonitor.on_train_batch_start/allocated_bytes.all.freed
# test_-DeviceStatsMonitor.on_train_batch_start/allocated_bytes.all.peak
# test_-DeviceStatsMonitor.on_train_batch_start/allocated_bytes.large_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/allocated_bytes.large_pool.current
# test_-DeviceStatsMonitor.on_train_batch_start/allocated_bytes.large_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_start/allocated_bytes.large_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_start/allocated_bytes.small_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/allocated_bytes.small_pool.current
# test_-DeviceStatsMonitor.on_train_batch_start/allocated_bytes.small_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_start/allocated_bytes.small_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_start/allocation.all.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/allocation.all.current
# test_-DeviceStatsMonitor.on_train_batch_start/allocation.all.freed
# test_-DeviceStatsMonitor.on_train_batch_start/allocation.all.peak
# test_-DeviceStatsMonitor.on_train_batch_start/allocation.large_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/allocation.large_pool.current
# test_-DeviceStatsMonitor.on_train_batch_start/allocation.large_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_start/allocation.large_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_start/allocation.small_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/allocation.small_pool.current
# test_-DeviceStatsMonitor.on_train_batch_start/allocation.small_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_start/allocation.small_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_start/inactive_split.all.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/inactive_split.all.current
# test_-DeviceStatsMonitor.on_train_batch_start/inactive_split.all.freed
# test_-DeviceStatsMonitor.on_train_batch_start/inactive_split.all.peak
# test_-DeviceStatsMonitor.on_train_batch_start/inactive_split.large_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/inactive_split.large_pool.current
# test_-DeviceStatsMonitor.on_train_batch_start/inactive_split.large_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_start/inactive_split.large_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_start/inactive_split.small_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/inactive_split.small_pool.current
# test_-DeviceStatsMonitor.on_train_batch_start/inactive_split.small_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_start/inactive_split.small_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_start/inactive_split_bytes.all.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/inactive_split_bytes.all.current
# test_-DeviceStatsMonitor.on_train_batch_start/inactive_split_bytes.all.freed
# test_-DeviceStatsMonitor.on_train_batch_start/inactive_split_bytes.all.peak
# test_-DeviceStatsMonitor.on_train_batch_start/inactive_split_bytes.large_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/inactive_split_bytes.large_pool.current
# test_-DeviceStatsMonitor.on_train_batch_start/inactive_split_bytes.large_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_start/inactive_split_bytes.large_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_start/inactive_split_bytes.small_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/inactive_split_bytes.small_pool.current
# test_-DeviceStatsMonitor.on_train_batch_start/inactive_split_bytes.small_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_start/inactive_split_bytes.small_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_start/max_split_size
# test_-DeviceStatsMonitor.on_train_batch_start/num_alloc_retries
# test_-DeviceStatsMonitor.on_train_batch_start/num_device_alloc
# test_-DeviceStatsMonitor.on_train_batch_start/num_device_free
# test_-DeviceStatsMonitor.on_train_batch_start/num_ooms
# test_-DeviceStatsMonitor.on_train_batch_start/num_sync_all_streams
# test_-DeviceStatsMonitor.on_train_batch_start/oversize_allocations.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/oversize_allocations.current
# test_-DeviceStatsMonitor.on_train_batch_start/oversize_allocations.freed
# test_-DeviceStatsMonitor.on_train_batch_start/oversize_allocations.peak
# test_-DeviceStatsMonitor.on_train_batch_start/oversize_segments.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/oversize_segments.current
# test_-DeviceStatsMonitor.on_train_batch_start/oversize_segments.freed
# test_-DeviceStatsMonitor.on_train_batch_start/oversize_segments.peak
# test_-DeviceStatsMonitor.on_train_batch_start/requested_bytes.all.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/requested_bytes.all.current
# test_-DeviceStatsMonitor.on_train_batch_start/requested_bytes.all.freed
# test_-DeviceStatsMonitor.on_train_batch_start/requested_bytes.all.peak
# test_-DeviceStatsMonitor.on_train_batch_start/requested_bytes.large_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/requested_bytes.large_pool.current
# test_-DeviceStatsMonitor.on_train_batch_start/requested_bytes.large_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_start/requested_bytes.large_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_start/requested_bytes.small_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/requested_bytes.small_pool.current
# test_-DeviceStatsMonitor.on_train_batch_start/requested_bytes.small_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_start/requested_bytes.small_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_start/reserved_bytes.all.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/reserved_bytes.all.current
# test_-DeviceStatsMonitor.on_train_batch_start/reserved_bytes.all.freed
# test_-DeviceStatsMonitor.on_train_batch_start/reserved_bytes.all.peak
# test_-DeviceStatsMonitor.on_train_batch_start/reserved_bytes.large_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/reserved_bytes.large_pool.current
# test_-DeviceStatsMonitor.on_train_batch_start/reserved_bytes.large_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_start/reserved_bytes.large_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_start/reserved_bytes.small_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/reserved_bytes.small_pool.current
# test_-DeviceStatsMonitor.on_train_batch_start/reserved_bytes.small_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_start/reserved_bytes.small_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_start/segment.all.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/segment.all.current
# test_-DeviceStatsMonitor.on_train_batch_start/segment.all.freed
# test_-DeviceStatsMonitor.on_train_batch_start/segment.all.peak
# test_-DeviceStatsMonitor.on_train_batch_start/segment.large_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/segment.large_pool.current
# test_-DeviceStatsMonitor.on_train_batch_start/segment.large_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_start/segment.large_pool.peak
# test_-DeviceStatsMonitor.on_train_batch_start/segment.small_pool.allocated
# test_-DeviceStatsMonitor.on_train_batch_start/segment.small_pool.current
# test_-DeviceStatsMonitor.on_train_batch_start/segment.small_pool.freed
# test_-DeviceStatsMonitor.on_train_batch_start/segment.small_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/active.all.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/active.all.current
# test_-DeviceStatsMonitor.on_validation_batch_end/active.all.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/active.all.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/active.large_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/active.large_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_end/active.large_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/active.large_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/active.small_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/active.small_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_end/active.small_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/active.small_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/active_bytes.all.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/active_bytes.all.current
# test_-DeviceStatsMonitor.on_validation_batch_end/active_bytes.all.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/active_bytes.all.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/active_bytes.large_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/active_bytes.large_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_end/active_bytes.large_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/active_bytes.large_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/active_bytes.small_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/active_bytes.small_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_end/active_bytes.small_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/active_bytes.small_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/allocated_bytes.all.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/allocated_bytes.all.current
# test_-DeviceStatsMonitor.on_validation_batch_end/allocated_bytes.all.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/allocated_bytes.all.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/allocated_bytes.large_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/allocated_bytes.large_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_end/allocated_bytes.large_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/allocated_bytes.large_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/allocated_bytes.small_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/allocated_bytes.small_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_end/allocated_bytes.small_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/allocated_bytes.small_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/allocation.all.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/allocation.all.current
# test_-DeviceStatsMonitor.on_validation_batch_end/allocation.all.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/allocation.all.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/allocation.large_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/allocation.large_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_end/allocation.large_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/allocation.large_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/allocation.small_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/allocation.small_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_end/allocation.small_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/allocation.small_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/inactive_split.all.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/inactive_split.all.current
# test_-DeviceStatsMonitor.on_validation_batch_end/inactive_split.all.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/inactive_split.all.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/inactive_split.large_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/inactive_split.large_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_end/inactive_split.large_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/inactive_split.large_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/inactive_split.small_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/inactive_split.small_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_end/inactive_split.small_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/inactive_split.small_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/inactive_split_bytes.all.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/inactive_split_bytes.all.current
# test_-DeviceStatsMonitor.on_validation_batch_end/inactive_split_bytes.all.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/inactive_split_bytes.all.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/inactive_split_bytes.large_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/inactive_split_bytes.large_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_end/inactive_split_bytes.large_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/inactive_split_bytes.large_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/inactive_split_bytes.small_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/inactive_split_bytes.small_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_end/inactive_split_bytes.small_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/inactive_split_bytes.small_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/max_split_size
# test_-DeviceStatsMonitor.on_validation_batch_end/num_alloc_retries
# test_-DeviceStatsMonitor.on_validation_batch_end/num_device_alloc
# test_-DeviceStatsMonitor.on_validation_batch_end/num_device_free
# test_-DeviceStatsMonitor.on_validation_batch_end/num_ooms
# test_-DeviceStatsMonitor.on_validation_batch_end/num_sync_all_streams
# test_-DeviceStatsMonitor.on_validation_batch_end/oversize_allocations.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/oversize_allocations.current
# test_-DeviceStatsMonitor.on_validation_batch_end/oversize_allocations.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/oversize_allocations.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/oversize_segments.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/oversize_segments.current
# test_-DeviceStatsMonitor.on_validation_batch_end/oversize_segments.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/oversize_segments.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/requested_bytes.all.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/requested_bytes.all.current
# test_-DeviceStatsMonitor.on_validation_batch_end/requested_bytes.all.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/requested_bytes.all.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/requested_bytes.large_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/requested_bytes.large_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_end/requested_bytes.large_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/requested_bytes.large_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/requested_bytes.small_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/requested_bytes.small_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_end/requested_bytes.small_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/requested_bytes.small_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/reserved_bytes.all.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/reserved_bytes.all.current
# test_-DeviceStatsMonitor.on_validation_batch_end/reserved_bytes.all.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/reserved_bytes.all.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/reserved_bytes.large_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/reserved_bytes.large_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_end/reserved_bytes.large_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/reserved_bytes.large_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/reserved_bytes.small_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/reserved_bytes.small_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_end/reserved_bytes.small_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/reserved_bytes.small_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/segment.all.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/segment.all.current
# test_-DeviceStatsMonitor.on_validation_batch_end/segment.all.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/segment.all.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/segment.large_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/segment.large_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_end/segment.large_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/segment.large_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_end/segment.small_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_end/segment.small_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_end/segment.small_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_end/segment.small_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/active.all.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/active.all.current
# test_-DeviceStatsMonitor.on_validation_batch_start/active.all.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/active.all.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/active.large_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/active.large_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_start/active.large_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/active.large_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/active.small_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/active.small_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_start/active.small_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/active.small_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/active_bytes.all.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/active_bytes.all.current
# test_-DeviceStatsMonitor.on_validation_batch_start/active_bytes.all.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/active_bytes.all.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/active_bytes.large_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/active_bytes.large_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_start/active_bytes.large_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/active_bytes.large_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/active_bytes.small_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/active_bytes.small_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_start/active_bytes.small_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/active_bytes.small_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/allocated_bytes.all.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/allocated_bytes.all.current
# test_-DeviceStatsMonitor.on_validation_batch_start/allocated_bytes.all.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/allocated_bytes.all.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/allocated_bytes.large_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/allocated_bytes.large_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_start/allocated_bytes.large_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/allocated_bytes.large_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/allocated_bytes.small_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/allocated_bytes.small_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_start/allocated_bytes.small_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/allocated_bytes.small_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/allocation.all.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/allocation.all.current
# test_-DeviceStatsMonitor.on_validation_batch_start/allocation.all.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/allocation.all.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/allocation.large_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/allocation.large_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_start/allocation.large_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/allocation.large_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/allocation.small_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/allocation.small_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_start/allocation.small_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/allocation.small_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/inactive_split.all.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/inactive_split.all.current
# test_-DeviceStatsMonitor.on_validation_batch_start/inactive_split.all.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/inactive_split.all.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/inactive_split.large_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/inactive_split.large_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_start/inactive_split.large_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/inactive_split.large_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/inactive_split.small_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/inactive_split.small_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_start/inactive_split.small_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/inactive_split.small_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/inactive_split_bytes.all.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/inactive_split_bytes.all.current
# test_-DeviceStatsMonitor.on_validation_batch_start/inactive_split_bytes.all.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/inactive_split_bytes.all.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/inactive_split_bytes.large_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/inactive_split_bytes.large_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_start/inactive_split_bytes.large_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/inactive_split_bytes.large_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/inactive_split_bytes.small_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/inactive_split_bytes.small_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_start/inactive_split_bytes.small_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/inactive_split_bytes.small_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/max_split_size
# test_-DeviceStatsMonitor.on_validation_batch_start/num_alloc_retries
# test_-DeviceStatsMonitor.on_validation_batch_start/num_device_alloc
# test_-DeviceStatsMonitor.on_validation_batch_start/num_device_free
# test_-DeviceStatsMonitor.on_validation_batch_start/num_ooms
# test_-DeviceStatsMonitor.on_validation_batch_start/num_sync_all_streams
# test_-DeviceStatsMonitor.on_validation_batch_start/oversize_allocations.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/oversize_allocations.current
# test_-DeviceStatsMonitor.on_validation_batch_start/oversize_allocations.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/oversize_allocations.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/oversize_segments.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/oversize_segments.current
# test_-DeviceStatsMonitor.on_validation_batch_start/oversize_segments.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/oversize_segments.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/requested_bytes.all.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/requested_bytes.all.current
# test_-DeviceStatsMonitor.on_validation_batch_start/requested_bytes.all.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/requested_bytes.all.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/requested_bytes.large_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/requested_bytes.large_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_start/requested_bytes.large_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/requested_bytes.large_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/requested_bytes.small_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/requested_bytes.small_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_start/requested_bytes.small_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/requested_bytes.small_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/reserved_bytes.all.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/reserved_bytes.all.current
# test_-DeviceStatsMonitor.on_validation_batch_start/reserved_bytes.all.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/reserved_bytes.all.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/reserved_bytes.large_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/reserved_bytes.large_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_start/reserved_bytes.large_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/reserved_bytes.large_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/reserved_bytes.small_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/reserved_bytes.small_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_start/reserved_bytes.small_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/reserved_bytes.small_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/segment.all.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/segment.all.current
# test_-DeviceStatsMonitor.on_validation_batch_start/segment.all.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/segment.all.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/segment.large_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/segment.large_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_start/segment.large_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/segment.large_pool.peak
# test_-DeviceStatsMonitor.on_validation_batch_start/segment.small_pool.allocated
# test_-DeviceStatsMonitor.on_validation_batch_start/segment.small_pool.current
# test_-DeviceStatsMonitor.on_validation_batch_start/segment.small_pool.freed
# test_-DeviceStatsMonitor.on_validation_batch_start/segment.small_pool.peak

# %% [markdown]
# ## Track and Visualize Experiments (basic)

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader, random_split
import torch.nn.functional as F

from lightning import LightningModule
from lightning import Trainer
from lightning.pytorch.callbacks import ModelCheckpoint
from lightning.pytorch.callbacks import EarlyStopping
from lightning.pytorch.callbacks import ModelSummary
from lightning.pytorch.loggers import CSVLogger

from torchvision import datasets
import torchvision.transforms as transforms

import os

# %%
# Load data sets
transform = transforms.ToTensor()
train_set = datasets.MNIST(root="../data/MNIST", download=True, train=True, transform=transform)
test_set = datasets.MNIST(root="../data/MNIST", download=True, train=False, transform=transform)

# use 20% of training data for validation
train_set_size = int(len(train_set) * 0.8)
valid_set_size = len(train_set) - train_set_size

# split the train set into two
seed = torch.Generator().manual_seed(42)
train_set, valid_set = random_split(train_set, [train_set_size, valid_set_size], generator=seed)

train_loader = DataLoader(train_set, batch_size=128, shuffle=True, num_workers=16, persistent_workers=True, pin_memory=True)
valid_loader = DataLoader(valid_set, batch_size=128, num_workers=16, persistent_workers=True, pin_memory=True)
test_loader = DataLoader(test_set, batch_size=1024, num_workers=16, persistent_workers=True, pin_memory=True)

# %% [markdown]
# ### Track metrics
# Metric visualization is the most basic but powerful way of understanding how your model is doing throughout the model development process.
# To track a metric, simply use the `self.log` method available inside the LightningModule

# %%
class Encoder(nn.Module):
    def __init__(self, in_dim=28*28, hidden_nodes_1=64, hidden_nodes_2=64, out_dim=4):
        super().__init__()
        self.ff = nn.Sequential(
            nn.Linear(in_dim, hidden_nodes_1),
            nn.ReLU(),
            nn.Linear(hidden_nodes_1, hidden_nodes_2),
            nn.ReLU(),
            nn.Linear(hidden_nodes_2, out_dim)
        )

    def forward(self, x):
        return self.ff(x)

class Decoder(nn.Module):
    def __init__(self, in_dim=4, hidden_nodes_1=64, hidden_nodes_2=64, out_dim=28*28):
        super().__init__()
        self.ff = nn.Sequential(
            nn.Linear(in_dim, hidden_nodes_1),
            nn.ReLU(),
            nn.Linear(hidden_nodes_1, hidden_nodes_2),
            nn.ReLU(),
            nn.Linear(hidden_nodes_2, out_dim)
        )

    def forward(self, x):
        return self.ff(x)

class LitAutoEncoder(LightningModule):
    def __init__(self, encoder, decoder, lr=1e-5, example_input_array=None):
        super().__init__()
        self.example_input_array = example_input_array
        self.encoder = encoder
        self.decoder = decoder
        self.lr = lr
        self.save_hyperparameters(ignore=["encoder", "decoder"])

    def training_step(self, batch, batch_idx):
        # training_step defines the train loop.
        loss = self._get_loss(batch)
        self.log("train/loss", loss, on_step=True, on_epoch=True)
        self.log("train_loss", loss, prog_bar=True, on_step=False, on_epoch=True)
        return loss

    def validation_step(self, batch, batch_idx):
        # this is the validation loop
        loss = self._get_loss(batch)
        self.log("val_loss", loss, prog_bar=True)

    def test_step(self, batch, batch_idx):
        # this is the test loop
        loss = self._get_loss(batch)
        self.log("test_loss", loss, prog_bar=True)

    def _get_loss(self, batch):
        x, _ = batch
        x = x.view(x.size(0), -1)
        x_hat = self.forward(x)
        loss = F.mse_loss(x_hat, x)
        return loss

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=self.lr)
        return optimizer

    def forward(self, x):
        z = self.encoder(x)
        x_hat = self.decoder(z)
        return x_hat

# %%
model = LitAutoEncoder(
    encoder=Encoder(
        in_dim=28*28,
        hidden_nodes_1=512,
        hidden_nodes_2=256,
        out_dim=100
    ),
    decoder=Decoder(
        in_dim=100,
        hidden_nodes_1=128,
        hidden_nodes_2=256,
        out_dim=28*28
    ),
    example_input_array=torch.Tensor(32, 1, 28*28)
)

# %%
logger = CSVLogger(
    save_dir='logs',
    name='find_bottlenecks',
    version=None
)

checkpoint_callback = ModelCheckpoint(
    dirpath=os.path.join(logger.log_dir, "checkpoints"),
    filename="autoencoder_best-{epoch:02d}-{val_loss:.3f}",
    monitor="val_loss",    
    mode="min",
    save_top_k=3,     # keep ONLY the best
    save_last=True    # ALSO save last.ckpt
)

early_stop_callback = EarlyStopping(
    monitor="val_loss",
    patience=3,
    verbose=False,
    mode="min"
)

model_summary_callback = ModelSummary(-1)
print(model_summary_callback)
# Out:
# <lightning.pytorch.callbacks.model_summary.ModelSummary object at 0x7fc11f815400>

# %%
from lightning.pytorch.loggers import TensorBoardLogger

logger = TensorBoardLogger("tb_logs", name="my_model")

# %%
trainer = Trainer(
    #profiler='simple',
    logger=logger,
    callbacks=[checkpoint_callback, early_stop_callback, model_summary_callback],
    accelerator="gpu",
    devices=1,
    max_epochs=100
)
# Out:
# /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib/python3.13/site-packages/lightning/fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /storage3/DSIP/rriva/tutorials/pl_tutorial/.venv/lib ...
# Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores

# %%
trainer.fit(model, train_loader, valid_loader)
trainer.test(model, test_loader)
# Out:
# You are using a CUDA device ('NVIDIA A40') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
#    | Name         | Type       | Params | Mode  | FLOPs  | In sizes     | Out sizes
# --------------------------------------------------------------------------------------------
# 0  | encoder      | Encoder    | 558 K  | train | 35.7 M | [32, 1, 784] | [32, 1, 100]
# 1  | encoder.ff   | Sequential | 558 K  | train | 35.7 M | [32, 1, 784] | [32, 1, 100]
# 2  | encoder.ff.0 | Linear     | 401 K  | train | 25.7 M | [32, 1, 784] | [32, 1, 512]
# 3  | encoder.ff.1 | ReLU       | 0      | train | 0      | [32, 1, 512] | [32, 1, 512]
# 4  | encoder.ff.2 | Linear     | 131 K  | train | 8.4 M  | [32, 1, 512] | [32, 1, 256]
# 5  | encoder.ff.3 | ReLU       | 0      | train | 0      | [32, 1, 256] | [32, 1, 256]
# 6  | encoder.ff.4 | Linear     | 25.7 K | train | 1.6 M  | [32, 1, 256] | [32, 1, 100]
# 7  | decoder      | Decoder    | 247 K  | train | 15.8 M | [32, 1, 100] | [32, 1, 784]
# 8  | decoder.ff   | Sequential | 247 K  | train | 15.8 M | [32, 1, 100] | [32, 1, 784]
# 9  | decoder.ff.0 | Linear     | 12.9 K | train | 819 K  | [32, 1, 100] | [32, 1, 128]
# 10 | decoder.ff.1 | ReLU       | 0      | train | 0      | [32, 1, 128] | [32, 1, 128]
# 11 | decoder.ff.2 | Linear     | 33.0 K | train | 2.1 M  | [32, 1, 128] | [32, 1, 256]
# 12 | decoder.ff.3 | ReLU       | 0      | train | 0      | [32, 1, 256] | [32, 1, 256]
# 13 | decoder.ff.4 | Linear     | 201 K  | train | 12.8 M | [32, 1, 256] | [32, 1, 784]
# --------------------------------------------------------------------------------------------
# 806 K     Trainable params
# 0         Non-trainable params
# 806 K     Total params
# 3.226     Total estimated model params size (MB)
# 14        Modules in train mode
# 0         Modules in eval mode
# 51.5 M    Total Flops
# Epoch 99: 100%|██████████| 375/375 [00:05<00:00, 72.77it/s, v_num=1, val_loss=0.0109, train_loss=0.0109]
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Epoch 99: 100%|██████████| 375/375 [00:05<00:00, 70.61it/s, v_num=1, val_loss=0.0109, train_loss=0.0109]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3,4,5,6,7]
# Testing DataLoader 0: 100%|██████████| 10/10 [00:00<00:00, 159.08it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_loss          0.010606293566524982
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_loss': 0.010606293566524982}]
